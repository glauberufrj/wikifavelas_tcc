# %%
# coleta_e_enriquecimento.py
#
# Análise e Melhorias:
# 1. Otimização da API: A função `obter_dados_verbete` foi refatorada para fazer
#    apenas UMA chamada de API por verbete, em vez de duas. Isso é feito
#    buscando todas as revisões de uma vez e processando a lista em Python
#    para encontrar a primeira e a última, reduzindo significativamente o tempo de execução.
# 2. Melhor Tratamento de Erros: A função agora retorna `None` em caso de falha,
#    tornando o código no loop principal mais limpo e seguro.
# 3. Type Hinting: Foram adicionadas dicas de tipo (ex: `-> list`, `session: requests.Session`)
#    para melhorar a legibilidade e a manutenibilidade do código.
# 4. Uso de f-strings e Pathlib: Modernização leve para melhor clareza.

import requests
import json
import os
import time
from datetime import datetime
from collections import defaultdict
from pathlib import Path
from typing import List, Dict, Tuple, Optional, Any

# --- Configurações Globais ---
WIKI_API_URL = "https://wikifavelas.com.br/api.php"
BASE_DIR = Path('dados')
BASE_DIR.mkdir(exist_ok=True) # Garante que o diretório de saída exista

# --- Funções de Coleta da API ---

def listar_todos_verbetes(session: requests.Session) -> List[Dict[str, Any]]:
    # Lista todos os verbetes da wiki, retornando uma lista de dicionários.
    print("[FASE 1/5] Listando todos os verbetes da wiki...")
    pages = []
    params = {
        'action': 'query', 'format': 'json', 'list': 'allpages',
        'aplimit': 'max', 'continue': ''
    }
    while True:
        try:
            response = session.get(WIKI_API_URL, params=params)
            response.raise_for_status()
            data = response.json()
            batch = data.get('query', {}).get('allpages', [])
            pages.extend(batch)
            cont = data.get('continue')
            if not cont:
                break
            params.update(cont)
        except requests.exceptions.RequestException as e:
            print(f"  [ERRO] Falha ao listar verbetes: {e}. Tentando novamente em 5s...")
            time.sleep(5)
    
    verbetes_info = [{
        'id': p['pageid'],
        'titulo': p['title'],
        'link': f"https://wikifavelas.com.br/{p['title'].replace(' ', '_')}"
    } for p in pages]
    
    print(f"  [INFO] Total de {len(verbetes_info)} verbetes encontrados.")
    return verbetes_info

def obter_dados_verbete_otimizado(page_id: int, session: requests.Session, tentativas: int = 3) -> Optional[Tuple]:
    # Coleta dados detalhados para um único verbete com UMA chamada de API.
    # Retorna None em caso de falha completa.
    params = {
        'action': 'query', 'format': 'json', 'pageids': page_id,
        'prop': 'revisions|links|categories',
        'rvlimit': 'max', 'rvprop': 'user|timestamp',
        'pllimit': 'max', 'cllimit': 'max'
    }
    
    for tentativa in range(1, tentativas + 1):
        try:
            response = session.get(WIKI_API_URL, params=params)
            response.raise_for_status()
            data = response.json()

            page_data = next(iter(data.get('query', {}).get('pages', {}).values()), None)
            
            if not page_data or 'revisions' not in page_data:
                return {}, [], [], "N/A", "N/A", "N/A"

            revisoes = page_data.get('revisions', [])
            
            # Processa edições
            usuarios = defaultdict(int)
            for rev in revisoes:
                usuarios[rev.get('user', 'Desconhecido')] += 1

            # Processa referências e categorias
            referencias = [link['title'] for link in page_data.get('links', [])]
            categorias = [cat['title'] for cat in page_data.get('categories', [])]
            
            # Encontra primeira e última edição na lista de revisões
            # A API retorna a mais recente primeiro por padrão
            data_ultima_edicao = revisoes[0].get('timestamp', 'N/A')
            autor_criacao = revisoes[-1].get('user', 'N/A')
            data_criacao = revisoes[-1].get('timestamp', 'N/A')

            return dict(usuarios), referencias, categorias, autor_criacao, data_criacao, data_ultima_edicao

        except (requests.exceptions.RequestException, json.JSONDecodeError) as e:
            print(f"  [ERRO] Tentativa {tentativa} para page_id {page_id} falhou: {e}. Aguardando...")
            time.sleep(2 * tentativa)

    print(f"  [FALHA] Todas as tentativas para page_id {page_id} falharam.")
    return None

# --- Script Principal ---

def main() -> None:
    session = requests.Session()
    verbetes_base = listar_todos_verbetes(session)
    
    verbetes_enriquecidos = []
    total_verbetes = len(verbetes_base)
    
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_filename = f'dados_api_{timestamp}.json'
    output_path = BASE_DIR / output_filename

    print("\n[FASE 2 a 5] Enriquecendo cada verbete com dados adicionais...")
    for i, verbete in enumerate(verbetes_base, start=1):
        print(f"  Processando {i}/{total_verbetes}: \"{verbete['titulo']}\"")
        
        dados_coletados = obter_dados_verbete_otimizado(verbete['id'], session)
        
        verbete_completo = verbete.copy()
        
        if dados_coletados:
            usuarios, refs, cats, autor, criacao, ultima = dados_coletados
            verbete_completo.update({
                'quantidade_edicoes': sum(usuarios.values()),
                'usuarios_edicoes': usuarios,
                'referencias': refs,
                'categorias': cats,
                'autor_criacao': autor,
                'data_criacao': criacao,
                'data_ultima_edicao': ultima
            })
        else: # Se a coleta falhou, preenche com dados vazios
             verbete_completo.update({
                'quantidade_edicoes': 0, 'usuarios_edicoes': {}, 'referencias': [],
                'categorias': [], 'autor_criacao': "Falha", 'data_criacao': "Falha",
                'data_ultima_edicao': "Falha"
            })

        verbetes_enriquecidos.append(verbete_completo)
        
        if i % 50 == 0 or i == total_verbetes:
            dados_para_salvar = {
                'total_verbetes': total_verbetes,
                'verbetes_completo': verbetes_enriquecidos
            }
            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(dados_para_salvar, f, ensure_ascii=False, indent=2)
            print(f"  [SALVO] Progresso salvo em '{output_path}' ({i} verbetes)")

    print(f"\n[FINALIZADO] Processo de coleta e enriquecimento concluído.")
    print(f"Arquivo final salvo em: '{output_path}'")

if __name__ == '__main__':
    main()
# Out:
# [FASE 1/5] Listando todos os verbetes da wiki...
#   [INFO] Total de 3552 verbetes encontrados.
#
# [FASE 2 a 5] Enriquecendo cada verbete com dados adicionais...
#   Processando 1/3552: ""A Expansão das Milícias no Rio de Janeiro: uso da força estatal, mercado imobiliário e grupos armados" (Resenha)"
#   Processando 2/3552: ""Bairro Veneza – Balsas - MA: Dados e Aspectos Socioeconômicos""
#   Processando 3/3552: ""Estudo sobre a distribuição das taxas de encarceramento nos estados brasileiros e principais variáveis associadas: Influências socioeconômicas e ideológicas (Resenha)""
#   Processando 4/3552: ""LUA"-Sem luta não tem vitória"
#   Processando 5/3552: ""O Sol na Cabeça" e a Realidade das Favelas do Rio de Janeiro"
#   Processando 6/3552: ""Security is everyone's duty": collective representations and new networks of post-pacification security policies in Rio de Janeiro (article)"
#   Processando 7/3552: ""Segurança é um dever de todos": representações coletivas e novas redes de políticas de segurança pós-pacificação no Rio de Janeiro (artigo)"
#   Processando 8/3552: "'Racismo ambiental deveria ser crime' (artigo)"
#   Processando 9/3552: "(Des)continuidades na experiência de "vida sob cerco" e na "sociabilidade violenta" (resenha)"
#   Processando 10/3552: "(Entrevista) Eron Santos - Morro da Providência"
#   Processando 11/3552: "(Re)enquadrando a pandemia através do discurso: reflexões a partir das favelas do Rio de Janeiro (artigo)"
#   Processando 12/3552: "+Lapena Habitar (projeto)"
#   Processando 13/3552: "100 mulheres negras brasileiras importantes"
#   Processando 14/3552: "146x Favela"
#   Processando 15/3552: "146x Favelas"
#   Processando 16/3552: "180 NELES"
#   Processando 17/3552: "180 NELES!"
#   Processando 18/3552: "1º Congresso Internacional "Falando sobre segurança pública na Maré""
#   Processando 19/3552: "1º Congresso Internacional - Falando sobre segurança pública na Maré"
#   Processando 20/3552: "1º Encontro Providência ODS3"
#   Processando 21/3552: "20 anos da chacina do Borel - sem justiça não há paz (live)"
#   Processando 22/3552: "22 anos da Lei 10.639/03"
#   Processando 23/3552: "2º Encontro Providência ODS3"
#   Processando 24/3552: "30 anos da chacina da Candelária - Rio de Janeiro"
#   Processando 25/3552: "32 anos: uma homenagem às mães de Acari"
#   Processando 26/3552: "32 anos da chacina de Acari"
#   Processando 27/3552: "3ª Conferência Livre de Saúde em Manguinhos"
#   Processando 28/3552: "3º Encontro Providência ODS3"
#   Processando 29/3552: "4º Encontro Providência ODS3"
#   Processando 30/3552: "54x Favelas"
#   Processando 31/3552: "7ª edição do Boletim Direito à Segurança Pública na Maré"
#   Processando 32/3552: "90x Favelas"
#   Processando 33/3552: "A.M.E - Associação de Moradores do Engenho (Itaguaí - Baixada Fluminense)"
#   Processando 34/3552: "A.M. e Amigos de Rio das Pedras"
#   Processando 35/3552: "ADPF 635"
#   Processando 36/3552: "ADPF 635 - ADPF das Favelas"
#   Processando 37/3552: "ADPF das Favelas: Em meio a mentiras do governador no Rio de Janeiro, Supremo decide sobre controle externo das polícias"
#   Processando 38/3552: "ADPF das Favelas: veja 6 pontos que devem ser considerados na criação do plano de redução da letalidade policial"
#   Processando 39/3552: "ADPF das Favelas - A democracia a passos de cágado (artigo)"
#   Processando 40/3552: "ADPF das Favelas - veja 6 pontos que devem ser considerados na criação do plano de redução da letalidade policial"
#   Processando 41/3552: "AMAR - Associação Multicultural de Artesãos da Restinga"
#   Processando 42/3552: "AME O TUCUNDUBA"
#   Processando 43/3552: "AMIGAS - Associação de Mulheres de Itaguaí Guerreiras e Articuladoras Sociais"
#   Processando 44/3552: "AMaréVê (coletivo)"
#   Processando 45/3552: "ASSOCIAÇÃO KAPI'WARA"
#   Processando 46/3552: "ATENDA - Dispositivo de Atendimento Integrado de Usuários de Crack, Álcool e Outras Drogas na Maré"
#   Processando 47/3552: "A ADPF das Favelas e a luta por uma perícia independente e autônoma"
#   Processando 48/3552: "A Cidade Estilhaçada: Reestruturação Econômica e Emancipações Municipais na Baixada Fluminense (livro)"
#   Processando 49/3552: "A Comunidade do Horto e a Luta por um Território Ancestral, no Contexto do Racismo Ambiental (artigo)"
#   Processando 50/3552: "A Comunidade do Horto e a Luta por um Território Ancestral no Contexto do Racismo Ambiental (artigo)"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (50 verbetes)
#   Processando 51/3552: "A Criminalidade Urbana Violenta no Brasil: Um Recorte Temático (resenha)"
#   Processando 52/3552: "A Criminalidade Urbana Violenta no Brasil - Um Recorte Temático (resenha)"
#   Processando 53/3552: "A Cultura do Skate - Papo na Laje - Episódio 17"
#   Processando 54/3552: "A Câmara do Rio contempla as favelas cariocas pela primeira vez no Plano Diretor; leis em diversas áreas, como infraestrutura, lazer, saúde e saúde mental"
#   Processando 55/3552: "A Educação Popular na Favela Chapéu Mangueira"
#   Processando 56/3552: "A Educação Tem Vez"
#   Processando 57/3552: "A Expansão das Milícias no Rio de Janeiro: uso da força estatal, mercado imobiliário e grupos armados" (Resenha)"
#   Processando 58/3552: "A Exposição Infantil Precoce às Redes Sociais - Episódio 7 (Podcast Ecos Digitais)"
#   Processando 59/3552: "A Festa da Penha - Romaria e demarcação de um lugar, diversão e reconquista da cidade"
#   Processando 60/3552: "A Festa da Penha - Romaria e demarcação de um lugar, diversão e reconquista da cidade (artigo)"
#   Processando 61/3552: "A Germinal Assessoria Terra Trabalho Educação"
#   Processando 62/3552: "A História de Marielle Uma Biografia Infantojuvenil (Livro)"
#   Processando 63/3552: "A História vista da laje as favelas e suas possibilidades de análise pelo olhar historiográfico"
#   Processando 64/3552: "A Noite das Estrelas está, esteve e sempre estará aqui"
#   Processando 65/3552: "A Proposta Educacional do Instituto Hoju"
#   Processando 66/3552: "A Questão Social e a Inclusão Produtiva nas Favelas Cariocas: Uma Análise Marxista no Âmbito do Serviço Social"
#   Processando 67/3552: "A Reforma Pereira Passos e a formação da(s) Favella(s)"
#   Processando 68/3552: "A Resiliência de Habitações de Gestão Comunitária Durante a Pandemia da Covid-19 (artigo)"
#   Processando 69/3552: "A Rocinha, a favela mais densamente povoada do Brasil"
#   Processando 70/3552: "A Rocinha, la favela la plus densément peuplée du Brésil"
#   Processando 71/3552: "A Rocinha Resiste"
#   Processando 72/3552: "A Teia: Brazil 's popular project of communication."
#   Processando 73/3552: "A Teia - Brazil 's popular project of communication"
#   Processando 74/3552: "A Vila Nazaré e o asfaltamento de histórias"
#   Processando 75/3552: "A Vizinha Faladeira e o Bairro do Santo Cristo: História, Cultura e Identidade"
#   Processando 76/3552: "A Voz do Lins"
#   Processando 77/3552: "A Voz do Morro"
#   Processando 78/3552: "A arte e a rua"
#   Processando 79/3552: "A cena aberta de consumo de drogas da rua Flávia Farnese na Maré (boletim)"
#   Processando 80/3552: "A chacina sem capuz e a estatização das mortes (artigo)"
#   Processando 81/3552: "A cidade coesiva enfrentando a estigmatização em bairros urbanos em desvantagens (relatório)"
#   Processando 82/3552: "A classe trabalhadora não nasce sabendo o que fazer (entrevista)"
#   Processando 83/3552: "A complexa sociabilidade dos jovens pentecostais nas periferias brasileiras (entrevista)"
#   Processando 84/3552: "A cor da mobilidade (artigo)"
#   Processando 85/3552: "A cor da morte (resenha)"
#   Processando 86/3552: "A cor da violência policial (relatório)"
#   Processando 87/3552: "A cor púrpura - Djonga (música)"
#   Processando 88/3552: "A crise da água e da energia nas favelas do Rio"
#   Processando 89/3552: "A escuta comunitária para a criação da moradia digna (debate)"
#   Processando 90/3552: "A esperança vem do lixo (Filme)"
#   Processando 91/3552: "A esperança vem do lixo - Filme"
#   Processando 92/3552: "A expansão das milícias no Rio de Janeiro (pesquisa)"
#   Processando 93/3552: "A favela ainda não venceu"
#   Processando 94/3552: "A favela como espaço da relação entre religião e violência (artigo)"
#   Processando 95/3552: "A favela no horário nobre da TV: Criminalidade, ostentação e estereótipo em A Força do Querer"
#   Processando 96/3552: "A favela no horário nobre da TV - Criminalidade, ostentação e estereótipo em A Força do Querer"
#   Processando 97/3552: "A favela para turista X a favela para os moradores (artigo)"
#   Processando 98/3552: "A favela que vivemos"
#   Processando 99/3552: "A favela quer pesquisar: NEPS-CEASM oferta oficinas para acesso ao mestrado (artigo)"
#   Processando 100/3552: "A favela quer pesquisar NEPS-CEASM oferta oficinas para acesso ao mestrado (artigo)"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (100 verbetes)
#   Processando 101/3552: "A favela é expressão de direitos humanos (artigo)"
#   Processando 102/3552: "A formação do Território do Morro do Estado"
#   Processando 103/3552: "A habitação não pode estar sujeita à lógica financeira (entrevista)"
#   Processando 104/3552: "A história sociojurídica das favelas cariocas"
#   Processando 105/3552: "A importância da prática do esporte em projeto social"
#   Processando 106/3552: "A importância dos conselheiros tutelares nas favelas e periferias do Rio de Janeiro (live)"
#   Processando 107/3552: "A infame atualidade de M8, um filme de Jeferson De"
#   Processando 108/3552: "A invisibilidade social depois da barricada"
#   Processando 109/3552: "A juventude das favelas e as consequências sociais da pandemia (artigo)"
#   Processando 110/3552: "A maconha medicinal não sobe o morro (Artigo)"
#   Processando 111/3552: "A maconha medicinal não sobe o morro (artigo)"
#   Processando 112/3552: "A mordaça da violência de gênero"
#   Processando 113/3552: "A onça pintada e a Favela do Arrelia"
#   Processando 114/3552: "A outra face das UPPs (artigo)"
#   Processando 115/3552: "A pandemia está nos deixando loucos! - violência doméstica, desemprego, fome... Como atender? (live)"
#   Processando 116/3552: "A peleja do slam contra as “inovações pedagógicas” (artigo)"
#   Processando 117/3552: "A polícia mentiu sobre a chacina do Jacarezinho (vídeo)"
#   Processando 118/3552: "A polícia ta aí"
#   Processando 119/3552: "A produção de dados em favelas e periferias em busca de memória, verdade e justiça (artigo)"
#   Processando 120/3552: "A proposta educacional do Instituto Hoju"
#   Processando 121/3552: "A radical imaginação política das mulheres negras brasileiras (livro)"
#   Processando 122/3552: "A recente produção artística de coletivos de periferias urbanas no Brasil: uma proposta de discussão metodológica"
#   Processando 123/3552: "A relação entre os gastos com segurança pública e o índice de violência intencional no Brasil"
#   Processando 124/3552: "A representatividade Indígena no Brasil - Episódio 3 (PodEco)"
#   Processando 125/3552: "A sensualidade em festa"
#   Processando 126/3552: "A sensualidade em festa (artigo)"
#   Processando 127/3552: "A superficialidade das relações: Como as redes sociais promovem conexões rasas e a falta de profundidade nas relações - Episódio 2 (Podcast Ecos Digitais)"
#   Processando 128/3552: "A superficialidade das relações - Como as redes sociais promovem conexões rasas e a falta de profundidade nas relações - Episódio 2 (podcast)"
#   Processando 129/3552: "A tecnologia de reconhecimento facial da PMERJ"
#   Processando 130/3552: "A tragédia no Rio Grande do Sul (artigo)"
#   Processando 131/3552: "A transformação da política na favela: desconstruindo a “ausência do Estado” (artigo)"
#   Processando 132/3552: "A urgência em tornar as favelas resilientes às mudanças climáticas"
#   Processando 133/3552: "A vida e as lutas de Marielle Franco (artigo)"
#   Processando 134/3552: "A violência política contra as mulheres negras (pesquisa)"
#   Processando 135/3552: "A visão fora da realidade do crescimento preto em nossa sociedade periférica."
#   Processando 136/3552: "A vitória do sincretismo: o desfile da Grande Rio no carnaval carioca de 2022 (artigo)"
#   Processando 137/3552: "A “Geração Like” Dependência dos jovens na validação social online - Episódio 3 (Podcast Ecos Digitais)"
#   Processando 138/3552: "Abayomi Juristas Negras (coletiva)"
#   Processando 139/3552: "Abdias do Nascimento"
#   Processando 140/3552: "Abolição das polícias: uma pesquisa de opinião sobre segurança pública"
#   Processando 141/3552: "Abolição das polícias uma pesquisa de opinião sobre segurança pública"
#   Processando 142/3552: "Abraço Campeão (campanha)"
#   Processando 143/3552: "Abusado - O Dono do Morro Dona Marta (livro)"
#   Processando 144/3552: "Acadêmicos do Cubango"
#   Processando 145/3552: "Acari"
#   Processando 146/3552: "Acervo da Laje"
#   Processando 147/3552: "Acessibilidade"
#   Processando 148/3552: "Acesso da população LGBT moradora de favelas aos serviços de saúde (artigo)"
#   Processando 149/3552: "Acesso à Justiça da Mulher"
#   Processando 150/3552: "Acorda Pedra"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (150 verbetes)
#   Processando 151/3552: "Acumulação social da violência"
#   Processando 152/3552: "Acumulação social do fracasso das políticas de segurança pública"
#   Processando 153/3552: "Adeus Aglomerados Subnormais - Parte 2 - O Direito à Moradia e o Estigma das Favelas na Nomenclatura Oficial"
#   Processando 154/3552: "Adeus Aglomerados Subnormais - Parte 2 O Direito à Moradia e o Estigma das Favelas na Nomenclatura Oficial"
#   Processando 155/3552: "Adeus Aglomerados Subnormais - Parte 3 Epistemologia Periférica no Desenho do Censo e a Apresentação de uma Nova Nomenclatura"
#   Processando 156/3552: "Adeus Aglomerados Subnormais - Seminário IBGE"
#   Processando 157/3552: "Adeus Aglomerados Subnormais Parte 1 - Diversidade Local, Potência e Pertencimento em um Novo Termo Oficial"
#   Processando 158/3552: "Adeus Aglomerados Subnormais Parte 1 - Diversidade Local Potência e Pertencimento em um Novo Termo Oficial"
#   Processando 159/3552: "Adriana Vianna - Fala na Audiência Pública da ADPF 635"
#   Processando 160/3552: "Afetividade LGBTQIA periférica - atravessamentos e estigmas"
#   Processando 161/3552: "Afirmativismo"
#   Processando 162/3552: "Afoxé Raízes Africanas"
#   Processando 163/3552: "Africa do Sul - Townships Squatter-camps (Phomolong)"
#   Processando 164/3552: "AfroSaúde"
#   Processando 165/3552: "Afroetnomatemática"
#   Processando 166/3552: "Afronário"
#   Processando 167/3552: "Afroturismo"
#   Processando 168/3552: "Afroturismo - Diagnóstico das Políticas Públicas no Brasil"
#   Processando 169/3552: "Agenda Belford Roxo 2030"
#   Processando 170/3552: "Agenda Campo Grande 2030"
#   Processando 171/3552: "Agenda Itaboraí 2030"
#   Processando 172/3552: "Agenda Japeri 2030"
#   Processando 173/3552: "Agenda Magé 2030"
#   Processando 174/3552: "Agenda Marielle Franco"
#   Processando 175/3552: "Agenda Meriti 2030"
#   Processando 176/3552: "Agenda Queimados 2030"
#   Processando 177/3552: "Agenda Realengo"
#   Processando 178/3552: "Agenda Realengo 2030"
#   Processando 179/3552: "Agenda Rio 2030"
#   Processando 180/3552: "Agenda Rio das Pedras 2030"
#   Processando 181/3552: "Agenda Rio das Pedras 2030 e a incidência em políticas públicas"
#   Processando 182/3552: "Agenda São Gonçalo 2030"
#   Processando 183/3552: "Agenda Vila Kennedy 2030"
#   Processando 184/3552: "Agenta Meriti 2030"
#   Processando 185/3552: "Agentes Comunitários de Saúde na linha de frente de combate a pandemia (depoimentos)"
#   Processando 186/3552: "Agentes comunitárias"
#   Processando 187/3552: "Agentes comunitários de saúde"
#   Processando 188/3552: "Aglomerado da Serra"
#   Processando 189/3552: "Agroecologia - episódio 6 (programa)"
#   Processando 190/3552: "Agroecologia em favelas"
#   Processando 191/3552: "Agência Lume - Rio das Pedras"
#   Processando 192/3552: "Agência de Notícias das Favelas"
#   Processando 193/3552: "Ainda posso falar (artigo)"
#   Processando 194/3552: "Ainda teremos Dublin? (livro)"
#   Processando 195/3552: "Alan Brum"
#   Processando 196/3552: "Alan Brum (Memória Viva)"
#   Processando 197/3552: "Alan Brum (entrevista)"
#   Processando 198/3552: "Aldear, aquilombar e TRANSformar"
#   Processando 199/3552: "Aldeia Maracanã"
#   Processando 200/3552: "Alemão"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (200 verbetes)
#   Processando 201/3552: "Alexandre Grabas (entrevista)"
#   Processando 202/3552: "Alexandro Cardoso (Alex Catador)"
#   Processando 203/3552: "Alexandro Cardoso Alex Catador"
#   Processando 204/3552: "Algoritmos e Favela"
#   Processando 205/3552: "Aliete Silva (entrevista)"
#   Processando 206/3552: "Alimentação orgânica como direito humano (artigo)"
#   Processando 207/3552: "Almanaque da Comunicação Sindical e Popular no Rio de Janeiro"
#   Processando 208/3552: "Almir Paulo (entrevista)"
#   Processando 209/3552: "Almirante Tamandaré"
#   Processando 210/3552: "Altair Antunes de Moraes (entrevista)"
#   Processando 211/3552: "Alto Santa Terezinha, Recife (PE)"
#   Processando 212/3552: "Aluguel (filme)"
#   Processando 213/3552: "Aluguel - O filme (filme)"
#   Processando 214/3552: "Aluguel O filme"
#   Processando 215/3552: "Aluguel Social"
#   Processando 216/3552: "Alvorada - Cartola (Música)"
#   Processando 217/3552: "Amar na Maré - a revolta de uma multidão"
#   Processando 218/3552: "Amarelinho"
#   Processando 219/3552: "Ambulatório Dedé"
#   Processando 220/3552: "Ambulatório Dedé - Sua criação, sua gestão e o término das atividades"
#   Processando 221/3552: "Ame o Tucunduba"
#   Processando 222/3552: "Amefricanidades: lugar, diferença e violência"
#   Processando 223/3552: "Amefricanidades - lugar, diferença e violência"
#   Processando 224/3552: "Amigos do Complexo do Alemão"
#   Processando 225/3552: "Amor"
#   Processando 226/3552: "Amor, Plástico e Barulho (filme)"
#   Processando 227/3552: "Amor é política e tecnologia na luta contra as mudanças climáticas"
#   Processando 228/3552: "Ana Leila Gonçalves (Mulher de Favela)"
#   Processando 229/3552: "Ana Paula Leandro (Mulher de Favela)"
#   Processando 230/3552: "Anazir Maria de Oliveira - Dona Zica (entrevista)"
#   Processando 231/3552: "Andréia de Jesus (PT - MG) - Ribeirão das Neves - BH"
#   Processando 232/3552: "Andréia de Jesus (PT / MG) - Ribeirão das Neves - BH"
#   Processando 233/3552: "Anielle Franco"
#   Processando 234/3552: "Anistia Internacional Brasil"
#   Processando 235/3552: "Anjos da Tia Stelinha"
#   Processando 236/3552: "Anjos da Tia Stellinha"
#   Processando 237/3552: "Antares"
#   Processando 238/3552: "Antes fosse brincadeira (documentário)"
#   Processando 239/3552: "Anthony Leeds (pesquisador)"
#   Processando 240/3552: "Anthony e Elizabeth Leeds (pesquisadores)"
#   Processando 241/3552: "Antirracismo nas redes sociais"
#   Processando 242/3552: "Antiéticos (coletivo)"
#   Processando 243/3552: "Análise das regras de grupos armados"
#   Processando 244/3552: "Análise de Estruturas de Violência e Direito (Grupo de Pesquisa)"
#   Processando 245/3552: "Análise do Ecossistema de Informação (IEA) da população LGBTQIAP+ negra da cidade do Rio de Janeiro"
#   Processando 246/3552: "Análises e propostas sobre a realidade do coronavírus nas favelas"
#   Processando 247/3552: "Apaixonadas por futebol - episódio 22 (programa)"
#   Processando 248/3552: "Apoie as favelas na luta contra o Coronavírus"
#   Processando 249/3552: "Apropriação cultural do capitalismo"
#   Processando 250/3552: "Aquilombamento"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (250 verbetes)
#   Processando 251/3552: "Aquilombamento Ballroom"
#   Processando 252/3552: "Aquilombar-se"
#   Processando 253/3552: "Areas de risco"
#   Processando 254/3552: "Arguição de Descumprimento de Preceito Fundamental - ADPF 635"
#   Processando 255/3552: "Armadura institucional e legitimação da violência policial: Um olhar a partir de São Paulo em tempos de pandemia"
#   Processando 256/3552: "Armadura institucional e legitimação da violência policial: Um olhar a partir de São Paulo em tempos de pandemia (resenha)"
#   Processando 257/3552: "Armadura institucional e legitimação da violência policial - Um olhar a partir de São Paulo em tempos de pandemia (resenha)"
#   Processando 258/3552: "Armar a guarda municipal é um atentado contra a vida (artigo)"
#   Processando 259/3552: "Armas nas mãos da Guarda Municipal: o medo que atinge guardas e trabalhadores informais no Rio de Janeiro"
#   Processando 260/3552: "Arquitetura com qualidade na habitação de interesse social (debate)"
#   Processando 261/3552: "Arquivos comunitários"
#   Processando 262/3552: "Arraiá das águas de Manguinhos"
#   Processando 263/3552: "Arrelia"
#   Processando 264/3552: "Arte, Cultura e Saúde Mental: cidadania, emancipação e criatividade (Manguinhos)"
#   Processando 265/3552: "Arte, Cultura e Saúde Mental - cidadania, emancipação e criatividade (Manguinhos)"
#   Processando 266/3552: "Arte de cria - bate-bolas e a cultura periférica na Zona Oeste do Rio de Janeiro"
#   Processando 267/3552: "Arte e a rua"
#   Processando 268/3552: "Artes urbanas e favelas"
#   Processando 269/3552: "Articles in English"
#   Processando 270/3552: "Articulação Recife de Luta"
#   Processando 271/3552: "Articulação e Movimento para Travestis e Transexuais de Pernambuco (Amotrans-PE)"
#   Processando 272/3552: "As Favelas - Sua grandeza e seu potencial econômico"
#   Processando 273/3552: "As Glorias e a segregação socioespacial em Uberlândia-MG"
#   Processando 274/3552: "As Igrejas Evangélicas nas Favelas"
#   Processando 275/3552: "As Márcias (filme)"
#   Processando 276/3552: "As Religiões no Rio"
#   Processando 277/3552: "As cinzas de Carolina já estão em Colômbia, mas queremos justiça"
#   Processando 278/3552: "As favelas no Plano Diretor da Cidade do Rio"
#   Processando 279/3552: "As favelas que a pandemia criou (artigo)"
#   Processando 280/3552: "As lutas do povo do Borel"
#   Processando 281/3552: "As melhores rodas de samba gratuitas do Rio de Janeiro (matéria)"
#   Processando 282/3552: "As mulheres contra os negócios da água"
#   Processando 283/3552: "As mães que dizem "não aos assassinatos" nas favelas - artigo"
#   Processando 284/3552: "Asfixia"
#   Processando 285/3552: "Assassinato de Marielle Franco - 14 de Março"
#   Processando 286/3552: "Assassinatos políticos na Baixada Fluminense"
#   Processando 287/3552: "Assessoria e Serviços a Projetos em Agricultura Alternativa - AS-PTA"
#   Processando 288/3552: "Assistência Técnica para Habitação de Interesse Social - ATHIS"
#   Processando 289/3552: "Associativismo de base comunitária na Cidade de Deus – O Movimento"
#   Processando 290/3552: "Associativismo e Memória (dimensão)"
#   Processando 291/3552: "Associativismo e Memória (eixo de análise)"
#   Processando 292/3552: "Associação Ambiental Mangueira Sustentável"
#   Processando 293/3552: "Associação Ballet Manguinhos"
#   Processando 294/3552: "Associação Beneficente AMAR"
#   Processando 295/3552: "Associação Camponesa para Educação, Cultura e Agricultura do Estado do Rio de Janeiro"
#   Processando 296/3552: "Associação Camponesa para Educação, Cultura e Agricultura do Estado do Rio de Janeiro - ACECARJ"
#   Processando 297/3552: "Associação Camponesa para Educação Cultura e Agricultura do Estado do Rio de Janeiro ACECARJ"
#   Processando 298/3552: "Associação Cultural Lanchonete"
#   Processando 299/3552: "Associação Despertar Sabedoria no Sol Nascente"
#   Processando 300/3552: "Associação Espaço Gaia"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (300 verbetes)
#   Processando 301/3552: "Associação Esportiva Regional"
#   Processando 302/3552: "Associação Kapi'wara"
#   Processando 303/3552: "Associação Missão Resplandecer (Duque de Caxias – RJ)"
#   Processando 304/3552: "Associação Mulheres de Atitude e Compromisso Social - AMAC"
#   Processando 305/3552: "Associação Pazear (Olinda – PE)"
#   Processando 306/3552: "Associação Recreativa e Cultural dos Blocos Carnavalescos de Angra dos Reis (ABCAR)"
#   Processando 307/3552: "Associação Satélite Prontidão (ASP)"
#   Processando 308/3552: "Associação Semeando Letras e Cidadania"
#   Processando 309/3552: "Associação Semente da Vida da Cidade de Deus ASVI CDD"
#   Processando 310/3552: "Associação das Mulheres e Amigos da Cachoeirinha"
#   Processando 311/3552: "Associação das Mulheres e Amigos da Cachoeirinha (AMAC)"
#   Processando 312/3552: "Associação de Cultura Arte e Esportes da Rocinha (ACAER Rocinha)"
#   Processando 313/3552: "Associação de Educação, Arte, Cultura e Agroecologia Sítio Agatha (Jaboatão dos Guararapes – PE)"
#   Processando 314/3552: "Associação de Educação Arte Cultura e Agroecologia Sítio Agatha (Jaboatão dos Guararapes – PE)"
#   Processando 315/3552: "Associação de Moradores Centro Pro Melhoramento da Bonfim"
#   Processando 316/3552: "Associação de Moradores do Condomínio e Amigos da Vila Mimosa (AMOCAVIM)"
#   Processando 317/3552: "Associação de Mulheres da Economia Solidária (AMESOL)"
#   Processando 318/3552: "Associação de Mulheres de Atitude com Compromisso Social (AMAC)"
#   Processando 319/3552: "Associação de Mulheres de Itaguaí Guerreiras e Articuladoras Sociais (AMIGAS)"
#   Processando 320/3552: "Associação de Prostitutas do Estado do Piauí (Teresina – PI)"
#   Processando 321/3552: "Associação de Remanescentes do Quilombo Dona Bilina"
#   Processando 322/3552: "Associação de moradores/movimentos sociais"
#   Processando 323/3552: "Associação de moradores e Movimentos Sociais"
#   Processando 324/3552: "Associação dos Moradores da Vila da Barca (AMVB)"
#   Processando 325/3552: "Associação dos Pescadores e Amigos da Lagoa de Piratininga"
#   Processando 326/3552: "Associação para o Desenvolvimento Solidário do Preventório"
#   Processando 327/3552: "Associações de Moradores do Complexo do Alemão"
#   Processando 328/3552: "Associações de moradores na Maré"
#   Processando 329/3552: "Associações de moradores precisam repensar seu papel nas favelas (entrevista)"
#   Processando 330/3552: "Atenção primária, empoderamento e direito à saúde"
#   Processando 331/3552: "Atinúké – Sobre o Pensamento de Mulheres Negras"
#   Processando 332/3552: "Atitudes que fazem a diferença: coronavírus e os coletivos nas favelas (artigo)"
#   Processando 333/3552: "Atitudes que fazem a diferença - coronavírus e os coletivos nas favelas (artigo)"
#   Processando 334/3552: "Atlas da Violência 2020 (pesquisa)"
#   Processando 335/3552: "Attitudes that make a difference: coronavirus and the collectives in the favelas (article)"
#   Processando 336/3552: "Até onde vai a liberdade da juventude?"
#   Processando 337/3552: "Até quando? (depoimento)"
#   Processando 338/3552: "Audiência Pública no Complexo do Alemão (2015)"
#   Processando 339/3552: "Aura da Luta"
#   Processando 340/3552: "Aura da Luta (Belo Horizonte – MG)"
#   Processando 341/3552: "Auto de Resistência (documentário)"
#   Processando 342/3552: "Auto de resistência: a omissão que mata"
#   Processando 343/3552: "Autodefinição"
#   Processando 344/3552: "Autora: Ana Clara Pereira Macedo"
#   Processando 345/3552: "Auxílio emergencial ou renda básica: benefício temporário ou direito de cidadania (live)"
#   Processando 346/3552: "Avenida Brasil - Instituto de Criatividade Social"
#   Processando 347/3552: "Ayó - crianças e fotografias"
#   Processando 348/3552: "Ação Participativa na Cidade de Deus - Projeto de pesquisa Construindo Juntos"
#   Processando 349/3552: "Ação Solidária Ilha contra o Coronavírus"
#   Processando 350/3552: "Ação contra a mudança climática - Episódio (podcast)"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (350 verbetes)
#   Processando 351/3552: "Ação de Mulheres pela Equidade (AME)"
#   Processando 352/3552: "Ações Afirmativas no acesso ao Ensino Superior"
#   Processando 353/3552: "Ações de combate ao covid-19 em Paraisópolis"
#   Processando 354/3552: "B.A.S.E. - Buscando Ajuda (para) Sonhos Executáveis"
#   Processando 355/3552: "BAIRRO JARDIM IRACEMA -ENTRE A ESPERANÇA E A NECESSIDADE: OS DESAFIOS PARA GARANTIR DIREITOS ESSENCIAIS"
#   Processando 356/3552: "BH: lições de lutas"
#   Processando 357/3552: "BK - Abebe Bikila Costa Santos"
#   Processando 358/3552: "BONDE"
#   Processando 359/3552: "BONDE - Coletivo de pesquisa sobre violências, sociabilidades e mobilidades urbanas"
#   Processando 360/3552: "Babado Periférico (web-série)"
#   Processando 361/3552: "Babilônia 2000 (filme)"
#   Processando 362/3552: "Babilônia Utopia (coletivo)"
#   Processando 363/3552: "Babilônia Utopia (collective)"
#   Processando 364/3552: "Bacaba (bairro)"
#   Processando 365/3552: "Baco Exu do Blues"
#   Processando 366/3552: "Bahia: Guerra às drogas garante privilégios da branquitude"
#   Processando 367/3552: "Baile Charme (Madureira)"
#   Processando 368/3552: "Baile Charme de Madureira"
#   Processando 369/3552: "Baile Funk"
#   Processando 370/3552: "Baile de Favela (música)"
#   Processando 371/3552: "Bailes Funk no Complexo do Alemão"
#   Processando 372/3552: "Bailão de Favela (música)"
#   Processando 373/3552: "Bairro Caramujo – Morro do Céu"
#   Processando 374/3552: "Bairro Emerson Santos"
#   Processando 375/3552: "Bairro Emerson Santos - Balsas-MA"
#   Processando 376/3552: "Bairro Grotões, Balsas, Maranhão"
#   Processando 377/3552: "Bairro Grotões, Balsas - MA"
#   Processando 378/3552: "Bairro Grotões: Balsas, Maranhão"
#   Processando 379/3552: "Bairro Grotões - Balsas, Maranhão"
#   Processando 380/3552: "Bairro Jardim Iracema - entre a esperança e a necessidade - os desafios para garantir direitos essenciais"
#   Processando 381/3552: "Bairro Jocy Barbosa – Balsas - MA"
#   Processando 382/3552: "BaixadaCine"
#   Processando 383/3552: "Baixada da Estrada Nova, Belém (PA)"
#   Processando 384/3552: "Baixadas da Condor"
#   Processando 385/3552: "Baixadas em Belém do Pará"
#   Processando 386/3552: "Bancada Negra de Porto Alegre"
#   Processando 387/3552: "Banco Maré"
#   Processando 388/3552: "Banco Nacional de Habitação (BNH) e a urbanização de favelas - Eliane Junqueira (entrevista)"
#   Processando 389/3552: "Bancos Comunitários"
#   Processando 390/3552: "Bancos Comunitários de Desenvolvimento como tecnologias de resiliência"
#   Processando 391/3552: "Bancos Comunitários de Desenvolvimento como tecnologias de resiliência: um olhar parcial sobre o microcrédito no Preventório"
#   Processando 392/3552: "Banksy: O Grito Contra a Violência Policial e a Desigualdade"
#   Processando 393/3552: "Barraco Adentro (podcast)"
#   Processando 394/3552: "Barracoteca Hans Christian Andersen (Complexo do Alemão)"
#   Processando 395/3552: "Barreira"
#   Processando 396/3552: "Barreira do Lins"
#   Processando 397/3552: "Barreira do Vasco"
#   Processando 398/3552: "Barricadas"
#   Processando 399/3552: "Batalha de Slam"
#   Processando 400/3552: "Batalha do Passinho (documentário)"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (400 verbetes)
#   Processando 401/3552: "Batalha do Tanque - SG"
#   Processando 402/3552: "Batalha dos Prazeres"
#   Processando 403/3552: "Bate-bolas e resistência do carnaval longe dos holofotes"
#   Processando 404/3552: "Becos, brechas, favelas: os corres de jovens produtores culturais de territórios populares"
#   Processando 405/3552: "Being Young Today - Episode 1 (Program)"
#   Processando 406/3552: "Beiru - Tancredo Neves"
#   Processando 407/3552: "BemTv"
#   Processando 408/3552: "Benedita da Silva"
#   Processando 409/3552: "Benedita da Silva (Memória Viva)"
#   Processando 410/3552: "Benedita da Silva (PT-RJ)"
#   Processando 411/3552: "Benedita da Silva (PT/RJ)"
#   Processando 412/3552: "Benny Briolly (PSOL-RJ) - Niteroi-Fonseca-RJ"
#   Processando 413/3552: "Benny Briolly (PSOL/RJ) - Niteroi / Fonseca - RJ"
#   Processando 414/3552: "Biblioteca Comunitária Caranguejo Tabaiares (Recife)"
#   Processando 415/3552: "Biblioteca Comunitária Wagner Vinício"
#   Processando 416/3552: "Biblioteca Comunitária de Heliópolis"
#   Processando 417/3552: "Big Boy e o Baile da Pesada"
#   Processando 418/3552: "Big Brother Santa Marta"
#   Processando 419/3552: "Biografias e Trajetórias Negras do Samba Carioca"
#   Processando 420/3552: "Biossistema de saneamento ecológico do Vale Encantado"
#   Processando 421/3552: "Bispo do Rosário Associação Cultural (BRASS)"
#   Processando 422/3552: "Bk"
#   Processando 423/3552: "Black Fair"
#   Processando 424/3552: "Bloco APAFUNK"
#   Processando 425/3552: "Bloco APAFUNK - Associação dos Profissionais e Amigos do Funk"
#   Processando 426/3552: "Bloco Afro Angola Janga"
#   Processando 427/3552: "Bloco Ai que Vergonha"
#   Processando 428/3552: "Bloco Aí que Vergonha"
#   Processando 429/3552: "Bloco Balanço do Jamelão"
#   Processando 430/3552: "Bloco Loucos Pela Vida"
#   Processando 431/3552: "Bloco Se Benze que Da"
#   Processando 432/3552: "Bloco Se Benze que Dá"
#   Processando 433/3552: "Bloco Se Benze que Dá!"
#   Processando 434/3552: "Bloco Unidos da Paixão do Andaraí"
#   Processando 435/3552: "Bloco Zona Mental"
#   Processando 436/3552: "Bom Jesus (Porto Alegre)"
#   Processando 437/3552: "Bom Jesus (bairro)"
#   Processando 438/3552: "Bombozila"
#   Processando 439/3552: "Bonde do Jack (coletivo)"
#   Processando 440/3552: "Boreart"
#   Processando 441/3552: "Borel massacre - April 16th, 2003"
#   Processando 442/3552: "Boêmios do Jardim Catarina"
#   Processando 443/3552: "Brasileiros na Mídia Internacional - Episódio 7 (podcast)"
#   Processando 444/3552: "Brasília de portas abertas às periferias? (Entrevista)"
#   Processando 445/3552: "Brasília de portas abertas às periferias (Entrevista)"
#   Processando 446/3552: "Brazil racista"
#   Processando 447/3552: "Brazilidade - Cultura & Identidade da Favela"
#   Processando 448/3552: "Brazilidade - Cultura e Identidade da Favela"
#   Processando 449/3552: "Brincadeiras de Rua: Origens e Influências"
#   Processando 450/3552: "Brincadeiras de rua - Origens e influências"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (450 verbetes)
#   Processando 451/3552: "Brota na Laje"
#   Processando 452/3552: "Bruna da Silva - Fala na Audiência Pública da ADPF 635"
#   Processando 453/3552: "Brás de Pina – Experiência de Urbanização de Favela"
#   Processando 454/3552: "Buraco Quente"
#   Processando 455/3552: "CDD Terra do Free"
#   Processando 456/3552: "CEDAC - Centro de Ação Comunitária"
#   Processando 457/3552: "CEDECA"
#   Processando 458/3552: "CEDECA Interlagos"
#   Processando 459/3552: "CICC - Centro Integrado de Comando e Controle"
#   Processando 460/3552: "CIEP"
#   Processando 461/3552: "CINE CLUBE TF"
#   Processando 462/3552: "CONCRIVI"
#   Processando 463/3552: "COR - Centro de Operações Rio"
#   Processando 464/3552: "CRISP (Centro de Estudos de Criminalidade e Segurança Pública)"
#   Processando 465/3552: "CUFA - Campanha esporte para todos"
#   Processando 466/3552: "Cabeça de Porco (cortiço)"
#   Processando 467/3552: "Cachoeirinha"
#   Processando 468/3552: "Cadastramento e a produção da demanda social por apartamentos, no Programa Minha Casa Minha Vida (artigo)"
#   Processando 469/3552: "Cadernos Identidades e Racialidades na Maré"
#   Processando 470/3552: "Cadu Barcellos"
#   Processando 471/3552: "Cadu Barcellos (personalidade)"
#   Processando 472/3552: "Caio Sael"
#   Processando 473/3552: "Caminhos Gerais: A omissão que traça a marginalização."
#   Processando 474/3552: "Caminhos Gerais (BAIRRO)"
#   Processando 475/3552: "Caminhos Gerais (bairro)"
#   Processando 476/3552: "Campanha Climão: mudanças climáticas nas favelas (campanha)"
#   Processando 477/3552: "Campanha Climão - mudanças climáticas nas favelas (campanha)"
#   Processando 478/3552: "Campanha Despejo Zero - Pela Vida no Campo e na Cidade"
#   Processando 479/3552: "Campanha Jovem Negro Vivo"
#   Processando 480/3552: "Campanha de Vacinação na Maré"
#   Processando 481/3552: "Camélias Coletivo"
#   Processando 482/3552: "Canal Transformadores"
#   Processando 483/3552: "Canal do Anil"
#   Processando 484/3552: "Canal do Anil: Resistência em Meio aos Destroços"
#   Processando 485/3552: "Canal do Cortado"
#   Processando 486/3552: "Cantagalo-Pavão-Pavãozinho"
#   Processando 487/3552: "Capa Comics"
#   Processando 488/3552: "Capicast"
#   Processando 489/3552: "Capoeira - episódio 9 (programa)"
#   Processando 490/3552: "Capítulo 4, Versículo 3 - Racionais MC's (música)"
#   Processando 491/3552: "Capítulo 4 Versículo 3 - Racionais MC's (música)"
#   Processando 492/3552: "Cara Preta (coletivo)"
#   Processando 493/3552: "Caramujo"
#   Processando 494/3552: "Carandiru Prison Massacre"
#   Processando 495/3552: "Caravana das Periferias"
#   Processando 496/3552: "Carla Felizardo (Mulher de Favela)"
#   Processando 497/3552: "Carlinhos Pandeiro de Ouro"
#   Processando 498/3552: "Carlos Duque: história de luta contra as remoções e pela organização dos moradores de favela"
#   Processando 499/3552: "Carlos Duque - história de luta contra as remoções e pela organização dos moradores de favela"
#   Processando 500/3552: "Carnaval Popular da Estrada Intendente Magalhães"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (500 verbetes)
#   Processando 501/3552: "Carnaval Popular de Pernambuco"
#   Processando 502/3552: "Carnaval Popular de Santana de Parnaíba (SP)"
#   Processando 503/3552: "Carnaval de Olinda e Recife"
#   Processando 504/3552: "Carnaval de Pernambuco"
#   Processando 505/3552: "Carnaval de rua da Estrada Intendente Magalhães"
#   Processando 506/3552: "Carnaval de rua na Maré"
#   Processando 507/3552: "Carol Dupré (entrevista)"
#   Processando 508/3552: "Carolina Maria de Jesus"
#   Processando 509/3552: "Carta compromisso da Rede Favela Sustentável comemorando a Rio 30"
#   Processando 510/3552: "Carta de Direitos Climáticos da Maré"
#   Processando 511/3552: "Carta dos Direitos Climáticos da Maré"
#   Processando 512/3552: "Cartilha das Rodas Culturais"
#   Processando 513/3552: "Cartilha de abordagem policial no Santa Marta"
#   Processando 514/3552: "Cartografia Decolonial das Juventudes Negras e Periféricas da Baixada"
#   Processando 515/3552: "Cartografia Decolonial das Juventudes Negras e Periféricas da Baixada Fluminense"
#   Processando 516/3552: "Cartografia Negra"
#   Processando 517/3552: "Cartografia Social Urbana (livro)"
#   Processando 518/3552: "Cartola"
#   Processando 519/3552: "Cartola (poema)"
#   Processando 520/3552: "Casa Amarela"
#   Processando 521/3552: "Casa Amarela (favela)"
#   Processando 522/3552: "Casa Brota (coletivo)"
#   Processando 523/3552: "Casa Fluminense"
#   Processando 524/3552: "Casa Grande (filme)"
#   Processando 525/3552: "Casa Marielle"
#   Processando 526/3552: "Casa Mãe Mulher (Belford Roxo – RJ)"
#   Processando 527/3552: "Casa Poéticas Negras"
#   Processando 528/3552: "Casa Poéticas Negras (Paraty – RJ)"
#   Processando 529/3552: "Casa Quilombel"
#   Processando 530/3552: "Casa Reviver"
#   Processando 531/3552: "Casa Reviver - Morro do Estado"
#   Processando 532/3552: "Casa Semente"
#   Processando 533/3552: "Casa da Baixa Costura"
#   Processando 534/3552: "Casa da Criança e do Adolescente"
#   Processando 535/3552: "Casa das Negas (Fortaleza – CE)"
#   Processando 536/3552: "Casa de Alvenaria (livro)"
#   Processando 537/3552: "Casa de Artes e Culturas Percilia Teles da Silva"
#   Processando 538/3552: "Casa de Caridade Seara de Boiadeiro"
#   Processando 539/3552: "Casa de Cultura Municipal M'Boi Mirim"
#   Processando 540/3552: "Casa de Cultura Tupinambá"
#   Processando 541/3552: "Casa do Nando"
#   Processando 542/3552: "Casas Marcadas (documentário)"
#   Processando 543/3552: "Casinhas em Campos dos Goytacazes (programa)"
#   Processando 544/3552: "Caso Amarildo"
#   Processando 545/3552: "Catarse Coletivo"
#   Processando 546/3552: "Categorias Temáticas"
#   Processando 547/3552: "Catia Cristina dos Santos (Mulher de Favela)"
#   Processando 548/3552: "Cavalcanti é Preto"
#   Processando 549/3552: "Caxambu do Salgueiro"
#   Processando 550/3552: "Caô"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (550 verbetes)
#   Processando 551/3552: "Ceará: a naturalização das violências"
#   Processando 552/3552: "Ceará - a naturalização das violências"
#   Processando 553/3552: "Celeste Estrela"
#   Processando 554/3552: "Censo Populacional da Maré (2012-2014)"
#   Processando 555/3552: "Censo das Favelas (2009)"
#   Processando 556/3552: "Censo de favelas e a produção autônoma de dados"
#   Processando 557/3552: "Censo popular, automapeamento e cartografia social da Providência"
#   Processando 558/3552: "Central de Movimentos Populares de São Paulo"
#   Processando 559/3552: "Central de Movimentos Populares de São Paulo - CMP/SP"
#   Processando 560/3552: "Central Única das Favelas (CUFA)"
#   Processando 561/3552: "Central Única das Favelas de Campo Grande/MS - CUFA"
#   Processando 562/3552: "Central Única das Favelas de Mato Grosso do Sul"
#   Processando 563/3552: "Central Única de Favelas (CUFA)"
#   Processando 564/3552: "Centro Comunitário Irmãos Kennedy"
#   Processando 565/3552: "Centro Comunitário Jardim Catarina (CCJC)"
#   Processando 566/3552: "Centro Comunitário do Rosarinho"
#   Processando 567/3552: "Centro Cultural Cambinda Estrela"
#   Processando 568/3552: "Centro Cultural Liga do Bem"
#   Processando 569/3552: "Centro Cultural de Cidadania e Economia Criativa MACquinho"
#   Processando 570/3552: "Centro Educacional Criança Futuro e Adolescência"
#   Processando 571/3552: "Centro Esportivo e Educacional Golfinhos da Baixada"
#   Processando 572/3552: "Centro Integrado de Educação Pública - CIEP"
#   Processando 573/3552: "Centro Revolucionário de Inovação e Arte - CRIA"
#   Processando 574/3552: "Centro de Arte Solar"
#   Processando 575/3552: "Centro de Articulação de Populações Marginalizadas - CEAP"
#   Processando 576/3552: "Centro de Atividades Sociais da Periferia CASP"
#   Processando 577/3552: "Centro de Criação de Imagem Popular - CECIP"
#   Processando 578/3552: "Centro de Cultura Popular da Baixada Fluminense CCPBF"
#   Processando 579/3552: "Centro de Defesa dos Direitos Humanos de Petrópolis"
#   Processando 580/3552: "Centro de Direitos Econômicos e Sociais (CDES)"
#   Processando 581/3552: "Centro de Estudos, Pesquisa, Documentação e Memória do Complexo do Alemão (CEPEDOCA)"
#   Processando 582/3552: "Centro de Estudos, Pesquisa, Documentação e Memória do Complexo do Alemão - CEPEDOCA"
#   Processando 583/3552: "Centro de Estudos da Metrópole"
#   Processando 584/3552: "Centro de Estudos de Segurança e Cidadania (CESeC)"
#   Processando 585/3552: "Centro de Estudos e Ação Social - CEAS"
#   Processando 586/3552: "Centro de Estudos e Ações Culturais e de Cidadania (CEACC)"
#   Processando 587/3552: "Centro de Estudos e Ações Culturais e de Cidadania - CEACC"
#   Processando 588/3552: "Centro de Estudos e Ações Solidárias da Maré"
#   Processando 589/3552: "Centro de Estudos em Segurança Pública e Direitos Humanos (CESPDH)"
#   Processando 590/3552: "Centro de Integração e Desenvolvimento Comunitário Comunidades em Ação - Mulheres do Salgueiro"
#   Processando 591/3552: "Centro de Integração na Serra da Misericórdia (CEM)"
#   Processando 592/3552: "Centro de Promoção da Saúde - CEDAPS"
#   Processando 593/3552: "Centro de Promoção da Saúde Cedaps"
#   Processando 594/3552: "Centros de Testagem na Maré e em Manguinhos para Covid-19"
#   Processando 595/3552: "Cerro Corá"
#   Processando 596/3552: "Cesarão"
#   Processando 597/3552: "Chacina da Baixada Fluminense, 31 de março de 2005"
#   Processando 598/3552: "Chacina da Candelária"
#   Processando 599/3552: "Chacina da Candelária - 23 de julho de 1993"
#   Processando 600/3552: "Chacina da Cidade de Deus - 19 de novembro de 2016"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (600 verbetes)
#   Processando 601/3552: "Chacina da Cidade de Deus - 25 de Abril de 2008"
#   Processando 602/3552: "Chacina da Cidade de Deus - 25 de abril de 2008"
#   Processando 603/3552: "Chacina da Lagartixa e Pedreira - 11 de outubro de 2007"
#   Processando 604/3552: "Chacina da Lagoinha - 4 de agosto de 2008"
#   Processando 605/3552: "Chacina da Maré"
#   Processando 606/3552: "Chacina da Maré - 06 de maio de 2019"
#   Processando 607/3552: "Chacina da Maré - 11 de junho de 2009"
#   Processando 608/3552: "Chacina da Maré - 20 de junho de 2018"
#   Processando 609/3552: "Chacina da Mineira"
#   Processando 610/3552: "Chacina da Mineira - 17 de abril de 2007"
#   Processando 611/3552: "Chacina da Nova Holanda - 24 de junho de 2013"
#   Processando 612/3552: "Chacina da Palmeira"
#   Processando 613/3552: "Chacina da Penha"
#   Processando 614/3552: "Chacina da Penha - 20 de agosto de 2018"
#   Processando 615/3552: "Chacina da Penha - 28 de maio de 2008"
#   Processando 616/3552: "Chacina da Praça Seca – 19 de maio de 2018"
#   Processando 617/3552: "Chacina da Rocinha"
#   Processando 618/3552: "Chacina da Rocinha - 11 de março de 2010"
#   Processando 619/3552: "Chacina da Rocinha - 24 de março de 2018"
#   Processando 620/3552: "Chacina da Via Show - 05 de dezembro de 2003"
#   Processando 621/3552: "Chacina da Vila Cruzeiro"
#   Processando 622/3552: "Chacina da Vila Cruzeiro - 11 de fevereiro de 2022"
#   Processando 623/3552: "Chacina da Vila Cruzeiro - 15 de abril de 2008"
#   Processando 624/3552: "Chacina da Vila Cruzeiro - 24 de maio de 2022"
#   Processando 625/3552: "Chacina de Acari"
#   Processando 626/3552: "Chacina de Acari - 26 de julho de 1990"
#   Processando 627/3552: "Chacina de Acari - 30 anos (matéria)"
#   Processando 628/3552: "Chacina de Acari 30 anos (matéria)"
#   Processando 629/3552: "Chacina de Campo Grande - 19 de agosto de 2008"
#   Processando 630/3552: "Chacina de Costa Barros - 28 de novembro de 2015"
#   Processando 631/3552: "Chacina de Nova Brasília - 18 de outubro de 1994"
#   Processando 632/3552: "Chacina de Nova Brasília - 8 de maio de 1995"
#   Processando 633/3552: "Chacina de Realengo - 03 de setembro de 2007"
#   Processando 634/3552: "Chacina de Vigário Geral"
#   Processando 635/3552: "Chacina de Vigário Geral - 29 de agosto de 1993"
#   Processando 636/3552: "Chacina do Borel"
#   Processando 637/3552: "Chacina do Borel - 16 de abril de 2003"
#   Processando 638/3552: "Chacina do Caju – 25 de novembro de 2017"
#   Processando 639/3552: "Chacina do Complexo do Alemão"
#   Processando 640/3552: "Chacina do Complexo do Alemão - 13 de fevereiro de 2007"
#   Processando 641/3552: "Chacina do Complexo do Alemão - 15 de maio de 2020"
#   Processando 642/3552: "Chacina do Complexo do Alemão - 27 de junho de 2007"
#   Processando 643/3552: "Chacina do Fallet-Fogueteiro - 08 de fevereiro de 2019"
#   Processando 644/3552: "Chacina do Itaguaí"
#   Processando 645/3552: "Chacina do Itaguaí - 15 de outubro de 2020"
#   Processando 646/3552: "Chacina do Jacarezinho"
#   Processando 647/3552: "Chacina do Jacarezinho: o massacre, a dor e a luta"
#   Processando 648/3552: "Chacina do Jacarezinho: o massacre, a dor e a luta (Relatório)"
#   Processando 649/3552: "Chacina do Jacarezinho - 06 de junho de 2007"
#   Processando 650/3552: "Chacina do Jacarezinho - 06 de maio de 2021"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (650 verbetes)
#   Processando 651/3552: "Chacina do Jacarezinho - 10 de janeiro de 2008"
#   Processando 652/3552: "Chacina do Jacarezinho - 11 de fevereiro de 2010"
#   Processando 653/3552: "Chacina do Jacarezinho - 30 de janeiro de 2008"
#   Processando 654/3552: "Chacina do Jacarezinho - o massacre, a dor e a luta (relatório)"
#   Processando 655/3552: "Chacina do Jacarezinho - o massacre a dor e a luta (relatório)"
#   Processando 656/3552: "Chacina do Jardim América - 25 de novembro de 2007"
#   Processando 657/3552: "Chacina do Maracanã - 10 de outubro de 1998"
#   Processando 658/3552: "Chacina do Morro do Engenho - 23 de junho de 2011"
#   Processando 659/3552: "Chacina do Morro do Juramento – 15 de setembro de 2017"
#   Processando 660/3552: "Chacina do Morro dos Macacos"
#   Processando 661/3552: "Chacina do Morro dos Macacos - 17 de outubro de 2009"
#   Processando 662/3552: "Chacina do Pan-Americano - 27 de junho de 2007"
#   Processando 663/3552: "Chacina do Parque Floresta - 24 de novembro de 2010"
#   Processando 664/3552: "Chacina do Parque Floresta - 3 de fevereiro de 2022"
#   Processando 665/3552: "Chacina do Parque Roseiral - 12 de janeiro de 2021"
#   Processando 666/3552: "Chacina do Parque Roseiral 12 de janeiro de 2021"
# ...
#   Processando 3340/3552: "Tuberculose na Rocinha (vídeo)"
#   Processando 3341/3552: "Tuiuti"
#   Processando 3342/3552: "Tuiuti (São Cristóvão)"
#   Processando 3343/3552: "Turbante não é adereço, é resistência ancestral"
#   Processando 3344/3552: "Turismo em favela"
#   Processando 3345/3552: "Tânia Alexandre Silva (Mulher de Favela)"
#   Processando 3346/3552: "Tópicos Especiais em Organização da Educação no Brasil (disciplina acadêmica)"
#   Processando 3347/3552: "UNEafro Brasil"
#   Processando 3348/3552: "UPP- A redução da favela a três letras: uma análise da política de segurança pública do Estado do Rio de Janeiro.(Resenha)"
#   Processando 3349/3552: "UPP- A redução da favela a três letras: uma análise da política de segurança pública do Estado do Rio de Janeiro (resenha)"
#   Processando 3350/3552: "UPP: a falência de um programa para mudar a polícia"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (3350 verbetes)
#   Processando 3351/3552: "UPP: visões e expectativas dos moradores de favelas ocupadas pela policia militar no Rio de Janeiro (artigo)"
#   Processando 3352/3552: "UPP: visões e expectativas dos moradores de favelas ocupadas pela policia militar no Rio de Janeiro (pesquisa)"
#   Processando 3353/3552: "UPP - A redução da favela a três letras - uma análise da política de segurança pública do Estado do Rio de Janeiro (resenha)"
#   Processando 3354/3552: "UPP Social, consultores da Onu-Habitat no Instituto Pereira Passos, do eixo social a tentativa de integrar os equipamentos públicos às favelas ocupadas pelas UPP´s"
#   Processando 3355/3552: "UPP Social - Projeto Cinemão"
#   Processando 3356/3552: "UPP – a redução da favela a três letras"
#   Processando 3357/3552: "Uga-Uga"
#   Processando 3358/3552: "Ulcera Social (poema)"
#   Processando 3359/3552: "Ultimas conversas (filme)"
#   Processando 3360/3552: "UmRio"
#   Processando 3361/3552: "Um Território Chamado Favela (filme)"
#   Processando 3362/3552: "Um carnaval entre a alegria e a desilusão – 30 dias (filme)"
#   Processando 3363/3552: "Um comunista - Canção de Caetano Veloso"
#   Processando 3364/3552: "Um dia estranho na favela"
#   Processando 3365/3552: "Um parque chamado Maré (artigo)"
#   Processando 3366/3552: "Um pouco da história do complexo do Lins"
#   Processando 3367/3552: "Uma história do crime organizado – 400 contra 1 (filme)"
#   Processando 3368/3552: "Unidos da Ponte (escola de samba)"
#   Processando 3369/3552: "Unidos do Jacarezinho"
#   Processando 3370/3552: "Unidos do Viradouro"
#   Processando 3371/3552: "Unifavela"
#   Processando 3372/3552: "Unifavela - A educação na Maré e o empoderamento da favela"
#   Processando 3373/3552: "Unifavelas (projeto)"
#   Processando 3374/3552: "Universidade das Quebradas"
#   Processando 3375/3552: "União Coletiva pela Zona Oeste"
#   Processando 3376/3552: "União de Negras e Negros pela Igualdade (Unegro)"
#   Processando 3377/3552: "União de Núcleos, Associações dos Moradores de Heliópolis e Região - UNAS"
#   Processando 3378/3552: "União dos Movimentos de Moradia São Paulo (UMM-SP)"
#   Processando 3379/3552: "União dos Trabalhadores Favelados (UTF)"
#   Processando 3380/3552: "União por Moradia Popular do Rio de Janeiro"
#   Processando 3381/3552: "Urbanismo Miliciano in Rio de Janeiro"
#   Processando 3382/3552: "Urbanização da favela Marcílio Dias - Maria Isabel Tostes (entrevista)"
#   Processando 3383/3552: "Urbanização de Favelas: Duas Experiências em Construção (livro)"
#   Processando 3384/3552: "Urbanização de Favelas - Duas Experiências em Construção (livro)"
#   Processando 3385/3552: "Urbanização de favelas no Rio de Janeiro (livro)"
#   Processando 3386/3552: "Urbanização do Pavão Pavãozinho - Denise Penna Firme (entrevista)"
#   Processando 3387/3552: "Urbanização do Pavão Pavãozinho - Kelson Senra (entrevista)"
#   Processando 3388/3552: "Urbanização do Pavão Pavãozinho - Paulo Saad (entrevista)"
#   Processando 3389/3552: "Urbano – Laboratório de Estudos da Cidade"
#   Processando 3390/3552: "Utanaan Reis"
#   Processando 3391/3552: "Utopia Negra"
#   Processando 3392/3552: "VILA KENNEDY: A AÇÃO DA FUNDAÇÃO LEÃO XIII NA FAVELA"
#   Processando 3393/3552: "Valmira (entrevista)"
#   Processando 3394/3552: "Valmiria (entrevista)"
#   Processando 3395/3552: "Valéria, Salvador (BA)"
#   Processando 3396/3552: "Valéria Barcellos (cantora)"
#   Processando 3397/3552: "Vamos Desenrolar: Produção de Conhecimento e Memórias (projeto)"
#   Processando 3398/3552: "Vamos falar de Pacificação (artigo)"
#   Processando 3399/3552: "Vanessa Daya (Mulher de Favela)"
#   Processando 3400/3552: "Vanise Gomes (entrevista)"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (3400 verbetes)
#   Processando 3401/3552: "Varal de lembranças"
#   Processando 3402/3552: "Vem Ni Mim Que Eu Sou Passinho"
#   Processando 3403/3552: "Vencendo barreiras"
#   Processando 3404/3552: "Veneza (bairro)"
#   Processando 3405/3552: "Verbeteiros"
#   Processando 3406/3552: "Verde e Pedra: assim como o planeta, a favela também tem limite."
#   Processando 3407/3552: "Verdejar e a Serra da Misericórdia"
#   Processando 3408/3552: "Vermelhinhos: Transporte Público Gratuito de Maricá"
#   Processando 3409/3552: "Vermelhinhos - Transporte Público Gratuito de Maricá"
#   Processando 3410/3552: "Veronica Costa (PL/RJ) - Morro do Juramento - RJ"
#   Processando 3411/3552: "Versão do Passado - A história e a memória do Chapéu Mangueira pelos moradores"
#   Processando 3412/3552: "Verônica Costa (PL-RJ) - Morro do Juramento - RJ"
#   Processando 3413/3552: "Verônica Costa (PL/RJ) - Morro do Juramento - RJ"
#   Processando 3414/3552: "Via Ápia (livro)"
#   Processando 3415/3552: "Viaduto Literário"
#   Processando 3416/3552: "Vicente Ferreira Mariano (1918-1971)"
#   Processando 3417/3552: "Vida Ballet - Only When I Dance (documentário)"
#   Processando 3418/3552: "Vida bandida (música)"
#   Processando 3419/3552: "Vida bandida (poema)"
#   Processando 3420/3552: "Vida bandida - Música"
#   Processando 3421/3552: "Vida e as lutas de Marielle Franco (artigo)"
#   Processando 3422/3552: "Vida na água e na terra - Episódio (podcast )"
#   Processando 3423/3552: "Vida social e política nas favelas (livro)"
#   Processando 3424/3552: "Vidas Precárias"
#   Processando 3425/3552: "Vidas adolescentes interrompidas: um estudo sobre mortes violentas no Rio de Janeiro (pesquisa)"
#   Processando 3426/3552: "Vidas negras e faveladas importam (debate)"
#   Processando 3427/3552: "Vidigal (bairro)"
#   Processando 3428/3552: "Vigário Geral"
#   Processando 3429/3552: "Vila Aliança"
#   Processando 3430/3552: "Vila Amaury (Brasília)"
#   Processando 3431/3552: "Vila Autódromo: remoção e resistência"
#   Processando 3432/3552: "Vila Benjamim Constant"
#   Processando 3433/3552: "Vila Benjamin Constant"
#   Processando 3434/3552: "Vila Canoas"
#   Processando 3435/3552: "Vila Catiri"
#   Processando 3436/3552: "Vila Catiri (Bangu)"
#   Processando 3437/3552: "Vila Cruzeiro"
#   Processando 3438/3552: "Vila Cruzeiro (Porto Alegre)"
#   Processando 3439/3552: "Vila Cruzeiro (bairro)"
#   Processando 3440/3552: "Vila Cândido"
#   Processando 3441/3552: "Vila Ipiranga"
#   Processando 3442/3552: "Vila Joaniza"
#   Processando 3443/3552: "Vila João Lopes"
#   Processando 3444/3552: "Vila Kennedy (bairro)"
#   Processando 3445/3552: "Vila Moreti"
#   Processando 3446/3552: "Vila Olímpica da Mangueira"
#   Processando 3447/3552: "Vila Operária (pesquisa)"
#   Processando 3448/3552: "Vila Paciência / Favela do Aço"
#   Processando 3449/3552: "Vila Parque da Cidade"
#   Processando 3450/3552: "Vila Piquirobi"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (3450 verbetes)
#   Processando 3451/3552: "Vila Planalto (Brasíia)"
#   Processando 3452/3552: "Vila Planalto (Brasília)"
#   Processando 3453/3552: "Vila Presidencial Quiririm"
#   Processando 3454/3552: "Vila Proletária Nossa Senhora da Penha"
#   Processando 3455/3552: "Vila Recreio 2 - Sonhos Demolidos (documentário)"
#   Processando 3456/3552: "Vila Recreio – broken dream"
#   Processando 3457/3552: "Vila Rica de Irajá"
#   Processando 3458/3552: "Vila Sapê"
#   Processando 3459/3552: "Vila São Jorge"
#   Processando 3460/3552: "Vila Turismo"
#   Processando 3461/3552: "Vila Vintém"
#   Processando 3462/3552: "Vila Vintém (Padre Miguel e Realengo)"
#   Processando 3463/3552: "Vila de Pescadores da Praia Grande"
#   Processando 3464/3552: "Vila do João"
#   Processando 3465/3552: "Vila dos Criadores"
#   Processando 3466/3552: "Vilas Olímpicas"
#   Processando 3467/3552: "Villa miseria"
#   Processando 3468/3552: "Vinicius Morais"
#   Processando 3469/3552: "Vinicius Santos (entrevista)"
#   Processando 3470/3552: "Vinte anos de PCC em São Paulo: o espaço entre governo e crime (artigo)"
#   Processando 3471/3552: "Vinícius Júnior"
#   Processando 3472/3552: "Violação dos direitos humanos é sentida ainda mais durante a pandemia (matéria)"
#   Processando 3473/3552: "Violações do direito à moradia em Ribeirão Preto e Região - 2ª Missão"
#   Processando 3474/3552: "Violence and Health of Favela Residents"
#   Processando 3475/3552: "Violence and health"
#   Processando 3476/3552: "Violencia verbal"
#   Processando 3477/3552: "Violência, Criminalidade, Segurança Pública e Justiça Criminal no Brasil: Uma Bibliografia (resenha)"
#   Processando 3478/3552: "Violência, Criminalidade, Segurança Pública e Justiça Criminal no Brasil - Uma Bibliografia (resenha)"
#   Processando 3479/3552: "Violência, Trabalho e Ilegalismos (Grupo de Pesquisa)"
#   Processando 3480/3552: "Violência, corpo e território: sobre a vida das mulheres na Maré"
#   Processando 3481/3552: "Violência Invisível: A Realidade de Mulheres Lésbicas e Bissexuais nas Periferias"
#   Processando 3482/3552: "Violência contra a mulher negra no Rio de Janeiro - O caso de Cláudia Silva Ferreira e a persistência do genocídio feminino negro"
#   Processando 3483/3552: "Violência de Estado, operações policiais, chacinas e... um plano"
#   Processando 3484/3552: "Violência de Estado: do meu lugar de escuta e de fala"
#   Processando 3485/3552: "Violência de Estado na Baixada Fluminense"
#   Processando 3486/3552: "Violência de Estado operações policiais chacinas e um plano"
#   Processando 3487/3552: "Violência e Racismo Obstétrico"
#   Processando 3488/3552: "Violência e Saúde de moradores de Favelas"
#   Processando 3489/3552: "Violência policial e saúde mental: 1/3 da população favelada sente ansiedade (matéria)"
#   Processando 3490/3552: "Violência policial e saúde mental - 1/3 da população favelada sente ansiedade (matéria)"
#   Processando 3491/3552: "Violência policial e saúde mental - um terço da população favelada sente ansiedade (matéria)"
#   Processando 3492/3552: "Violência urbana, Segurança Pública e Favelas - O Caso do Rio de Janeiro Atual (resenha)"
#   Processando 3493/3552: "Violência urbana no Brasil ontem e hoje (disciplina acadêmica)"
#   Processando 3494/3552: "Violência verbal"
#   Processando 3495/3552: "Violências de gênero em contextos militarizados"
#   Processando 3496/3552: "Violências em territórios faccionados do Nordeste do Brasil: notas sobre as situações do Rio Grande do Norte e do Ceará (artigo)"
#   Processando 3497/3552: "Viradão Cultural"
#   Processando 3498/3552: "Visita a Rádio Comunitária Santa Marta"
#   Processando 3499/3552: "Visita à Rádio Comunitária Santa Marta"
#   Processando 3500/3552: "Visão Periférica"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (3500 verbetes)
#   Processando 3501/3552: "Visões Periféricas (Festival)"
#   Processando 3502/3552: "Vivendo com os pés no esgoto"
#   Processando 3503/3552: "Viver sem guerra? Poderes locais e relações degênero no cotidiano popular"
#   Processando 3504/3552: "Viver sem guerra Poderes locais e relações degênero no cotidiano popular"
#   Processando 3505/3552: "Vivir sin guerra - Poderes locales y relaciones de género en la vida cotidiana popular (reseña)"
#   Processando 3506/3552: "Vivência das transmasculinidades e as corporalidades suicidadas"
#   Processando 3507/3552: "Voz Calada"
#   Processando 3508/3552: "Voz das Comunidades"
#   Processando 3509/3552: "Vozes da UFRJ - Episódio 3 (podcast)"
#   Processando 3510/3552: "Vozes da UFRJ - Episódio 5 (podcast)"
#   Processando 3511/3552: "Vozes da dor, da luta e da resistência das mulheres-mães de vítimas da violência de estado no Brasil (relatório)"
#   Processando 3512/3552: "Vozes da dor, da luta e da resistência das mulheres/mães de vítimas da violência de estado no Brasil (relatório)"
#   Processando 3513/3552: "Vozes das Comunidades"
#   Processando 3514/3552: "Vozes periféricas: expansão, imersão e diálogo na obra dos Racionais MC's (artigo)"
#   Processando 3515/3552: "Vozes periféricas - expansão, imersão e diálogo na obra dos Racionais MC's (artigo)"
#   Processando 3516/3552: "Vânia Dutra (entrevista)"
#   Processando 3517/3552: "Waka Waka na Maré (música)"
#   Processando 3518/3552: "Wescla Vasconcelos (entrevista)"
#   Processando 3519/3552: "Whake"
#   Processando 3520/3552: "What is advocacy?"
#   Processando 3521/3552: "WhatsApp nas Favelas"
#   Processando 3522/3552: "Wikifavelas - Dicionário de Favelas Marielle Franco: um modelo de sistematização Wiki na organização e representação da informação (artigo)"
#   Processando 3523/3552: "Wikifavelas - Dictionary of shanty town Marielle Franco, a model of Wiki systematization in the organization and representation of information (article)"
#   Processando 3524/3552: "Wikifavelas - Dictionary of shanty town Marielle Franco: a model of Wiki systematization in the organization and representation of information (article)"
#   Processando 3525/3552: "Wikifavelas no Outras Palavras"
#   Processando 3526/3552: "Woman Fem"
#   Processando 3527/3552: "Xenofobia"
#   Processando 3528/3552: "Xica Manicongo: Memória e Resistência Trans no Brasil Colonial"
#   Processando 3529/3552: "Yellow September - for a public mental health policy for favelas and peripheries"
#   Processando 3530/3552: "Yoga Marginal"
#   Processando 3531/3552: "Yoga de Rua"
#   Processando 3532/3552: "Zona Oeste Ativa - produção cultural na Z.O"
#   Processando 3533/3552: "Zona Oeste Ativa - produção cultural na ZO"
#   Processando 3534/3552: "Zumbi dos Palmares/Nova Luz"
#   Processando 3535/3552: "Zumbi dos Palmares/Nova Luz (favela)"
#   Processando 3536/3552: "Zumbi dos Palmares (Manaus)"
#   Processando 3537/3552: "Zuri Moura (personalidade)"
#   Processando 3538/3552: "¿Vivir sin guerra? Poderes locales y relaciones de género en la vida cotidiana popular (Revista)"
#   Processando 3539/3552: "África do Sul - Townships / Squatter-camps (Phomolong)"
#   Processando 3540/3552: "Água e saneamento básico na Rocinha"
#   Processando 3541/3552: "Água e saneamento básico na Rocinha (RJ)"
#   Processando 3542/3552: "Água não é mercadoria - Como a privatização pode impactar ainda mais as vidas nas favelas e periferias? (artigo)"
#   Processando 3543/3552: "Água não é mercadoria - Como a privatização pode impactar ainda mais as vidas nas favelas e periferias (artigo)"
#   Processando 3544/3552: "Águas do Caju"
#   Processando 3545/3552: "Áreas de Especial Interesse Social (AEIS)"
#   Processando 3546/3552: "Áreas de risco"
#   Processando 3547/3552: "É fita"
#   Processando 3548/3552: "“A pandemia está nos deixando loucos!” - violência doméstica, desemprego, fome... Como atender? (live)"
#   Processando 3549/3552: "“Casas de “tomar conta” e creches públicas: relações de cuidados e interdependência entre periferias e Estado”"
#   Processando 3550/3552: "“Fogo nos racistas!”: a pedagogia decolonial do rap (artigo)"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (3550 verbetes)
#   Processando 3551/3552: "“O Nó é o que constrói Nós” (artigo)"
#   Processando 3552/3552: "“Violência urbana", Segurança Pública e Favelas - O Caso do Rio de Janeiro Atual (resenha)"
#   [SALVO] Progresso salvo em 'dadosWikifavelas20250511\dados_completos_20250812_125616.json' (3552 verbetes)
#
# [FINALIZADO] Processo de coleta e enriquecimento concluído.
# Arquivo final salvo em: 'dadosWikifavelas20250511\dados_completos_20250812_125616.json'
