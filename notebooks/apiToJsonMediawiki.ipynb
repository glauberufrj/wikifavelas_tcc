# %%
# Análise e Melhorias:
# 1. Otimização da API: A função `obter_dados_verbete` foi refatorada para fazer
#    apenas UMA chamada de API por verbete.
# 2. Melhor Tratamento de Erros: A função agora retorna `None` em caso de falha.
# 3. Type Hinting: Adicionadas dicas de tipo para legibilidade.
# 4. Caminho de Saída Corrigido: O `BASE_DIR` foi ajustado para a estrutura de pastas do projeto.
# 5. Filtros Corretos: Os filtros de namespace e redirecionamento foram aplicados
#    na função correta (`listar_todos_verbetes`) para garantir um dataset limpo.

import requests
import json
import os
import time
from datetime import datetime
from collections import defaultdict
from pathlib import Path
from typing import List, Dict, Tuple, Optional, Any

# --- Configurações Globais ---
WIKI_API_URL = "https://wikifavelas.com.br/api.php"
# O script está em 'notebooks/', então o caminho para a pasta 'dados' é '../dados'
BASE_DIR = Path('../dados') 
BASE_DIR.mkdir(exist_ok=True) # Garante que o diretório de saída exista

# --- Funções de Coleta da API ---

def listar_todos_verbetes(session: requests.Session) -> List[Dict[str, Any]]:
    # Lista todos os verbetes REAIS (não-redirecionamentos) do namespace principal.
    print("[FASE 1/5] Listando todos os verbetes REAIS da wiki (filtrando redirecionamentos)...")
    pages = []
    params = {
        'action': 'query', 'format': 'json', 'list': 'allpages',
        'apnamespace': 0,                 # <-- FILTRO 1: Garante namespace principal.
        'apfilterredir': 'nonredirects',  # <-- FILTRO 2: Garante que não são redirecionamentos.
        'aplimit': 'max', 'continue': ''
    }
    while True:
        try:
            response = session.get(WIKI_API_URL, params=params)
            response.raise_for_status()
            data = response.json()
            batch = data.get('query', {}).get('allpages', [])
            pages.extend(batch)
            cont = data.get('continue')
            if not cont:
                break
            params.update(cont)
        except requests.exceptions.RequestException as e:
            print(f"  [ERRO] Falha ao listar verbetes: {e}. Tentando novamente em 5s...")
            time.sleep(5)
    
    verbetes_info = [{
        'id': p['pageid'],
        'titulo': p['title'],
        'link': f"https://wikifavelas.com.br/{p['title'].replace(' ', '_')}"
    } for p in pages]
    
    print(f"  [INFO] Total de {len(verbetes_info)} verbetes reais encontrados.")
    return verbetes_info

def obter_dados_verbete_otimizado(page_id: int, session: requests.Session, tentativas: int = 3) -> Optional[Tuple]:
    # Coleta dados detalhados para um único verbete com UMA chamada de API.
    params = {
        'action': 'query', 'format': 'json', 'pageids': page_id,
        'prop': 'revisions|links|categories',
        'rvlimit': 'max', 'rvprop': 'user|timestamp',
        'pllimit': 'max', 'cllimit': 'max'
    }
    
    for tentativa in range(1, tentativas + 1):
        try:
            response = session.get(WIKI_API_URL, params=params)
            response.raise_for_status()
            data = response.json()

            page_data = next(iter(data.get('query', {}).get('pages', {}).values()), None)
            
            if not page_data or 'revisions' not in page_data:
                return {}, [], [], "N/A", "N/A", "N/A"

            revisoes = page_data.get('revisions', [])
            
            usuarios = defaultdict(int)
            for rev in revisoes:
                usuarios[rev.get('user', 'Desconhecido')] += 1

            referencias = [link['title'] for link in page_data.get('links', []) if 'title' in link]
            categorias = [cat['title'] for cat in page_data.get('categories', []) if 'title' in cat]
            
            data_ultima_edicao = revisoes[0].get('timestamp', 'N/A')
            autor_criacao = revisoes[-1].get('user', 'N/A')
            data_criacao = revisoes[-1].get('timestamp', 'N/A')

            return dict(usuarios), referencias, categorias, autor_criacao, data_criacao, data_ultima_edicao

        except (requests.exceptions.RequestException, json.JSONDecodeError) as e:
            print(f"  [ERRO] Tentativa {tentativa} para page_id {page_id} falhou: {e}. Aguardando...")
            time.sleep(2 * tentativa)

    print(f"  [FALHA] Todas as tentativas para page_id {page_id} falharam.")
    return None

# --- Script Principal ---

def main() -> None:
    session = requests.Session()
    verbetes_base = listar_todos_verbetes(session)
    
    verbetes_enriquecidos = []
    total_verbetes = len(verbetes_base)
    
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_filename = f'dados_api_{timestamp}.json'
    output_path = BASE_DIR / output_filename

    print("\n[FASE 2 a 5] Enriquecendo cada verbete com dados adicionais...")
    for i, verbete in enumerate(verbetes_base, start=1):
        print(f"  Processando {i}/{total_verbetes}: \"{verbete['titulo']}\"")
        
        dados_coletados = obter_dados_verbete_otimizado(verbete['id'], session)
        
        verbete_completo = verbete.copy()
        
        if dados_coletados:
            usuarios, refs, cats, autor, criacao, ultima = dados_coletados
            verbete_completo.update({
                'quantidade_edicoes': sum(usuarios.values()),
                'usuarios_edicoes': usuarios,
                'referencias': refs,
                'categorias': cats,
                'autor_criacao': autor,
                'data_criacao': criacao,
                'data_ultima_edicao': ultima
            })
        else:
            verbete_completo.update({
                'quantidade_edicoes': 0, 'usuarios_edicoes': {}, 'referencias': [],
                'categorias': [], 'autor_criacao': "Falha", 'data_criacao': "Falha",
                'data_ultima_edicao': "Falha"
            })

        verbetes_enriquecidos.append(verbete_completo)
        
        if i % 50 == 0 or i == total_verbetes:
            dados_para_salvar = {
                'total_verbetes': len(verbetes_enriquecidos),
                'verbetes_completo': verbetes_enriquecidos
            }
            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(dados_para_salvar, f, ensure_ascii=False, indent=2)
            print(f"  [SALVO] Progresso salvo em '{output_path}' ({i} verbetes)")

    print(f"\n[FINALIZADO] Processo de coleta e enriquecimento concluído.")
    print(f"Arquivo final salvo em: '{output_path}'")

if __name__ == '__main__':
    main()
# Out:
# [FASE 1/5] Listando todos os verbetes REAIS da wiki (filtrando redirecionamentos)...
#   [INFO] Total de 3272 verbetes reais encontrados.
#
# [FASE 2 a 5] Enriquecendo cada verbete com dados adicionais...
#   Processando 1/3272: ""Proibidão 2021" e o retrato da realidade na Pavuna."
#   Processando 2/3272: ""Religião, desenvolvimento e violência" por Paul Freston (resenha)."
#   Processando 3/3272: "100 mulheres negras brasileiras importantes"
#   Processando 4/3272: "146x Favelas"
#   Processando 5/3272: "180 NELES"
#   Processando 6/3272: "1º Encontro Providência ODS3"
#   Processando 7/3272: "20 anos da chacina do Borel - sem justiça não há paz (live)"
#   Processando 8/3272: "22 anos da Lei 10.639/03"
#   Processando 9/3272: "2º Encontro Providência ODS3"
#   Processando 10/3272: "30 anos da chacina da Candelária - Rio de Janeiro"
#   Processando 11/3272: "32 anos: uma homenagem às mães de Acari"
#   Processando 12/3272: "32 anos da chacina de Acari"
# ...

# %%
# script_validacao_contagem_final.py
#
# Objetivo: Realizar uma contagem precisa dos verbetes REAIS (não-redirecionamentos)
# no namespace principal da API do Wikifavelas.

import requests
import time
from typing import List, Dict, Any

# --- Configuração ---
WIKI_API_URL = "https://wikifavelas.com.br/api.php"

# --- Função de Coleta da API ---

def contar_verbetes_reais(session: requests.Session) -> int:
    """
    Lista e conta todos os verbetes reais (não-redirecionamentos) do namespace
    principal (índice 0) da wiki. Retorna o número total encontrado.
    """
    print("[INICIANDO VALIDAÇÃO] Listando verbetes reais (não-redirecionamentos)...")
    
    total_verbetes = 0
    params = {
        'action': 'query',
        'format': 'json',
        'list': 'allpages',
        'apnamespace': 0,                 # Filtra para o namespace de artigos/verbetes.
        'apfilterredir': 'nonredirects',  # Filtra para excluir páginas de redirecionamento.
        'aplimit': 'max',
        'continue': ''
    }
    
    while True:
        try:
            response = session.get(WIKI_API_URL, params=params)
            response.raise_for_status()
            data = response.json()
            
            batch = data.get('query', {}).get('allpages', [])
            if batch:
                total_verbetes += len(batch)
                print(f"  [INFO] Lote recebido. Total parcial: {total_verbetes} verbetes...")
            
            cont = data.get('continue')
            if not cont:
                break  # Encerra o loop se não houver mais páginas de resultados.
            
            params.update(cont)
            
        except requests.exceptions.RequestException as e:
            print(f"  [ERRO] Falha na comunicação com a API: {e}. Tentando novamente em 5 segundos...")
            time.sleep(5)
            
    return total_verbetes

# --- Script Principal ---

def main() -> None:
    """
    Função principal que orquestra a validação.
    """
    session = requests.Session()
    
    numero_final_verbetes = contar_verbetes_reais(session)
    
    print("\n" + "="*50)
    print("[VALIDAÇÃO CONCLUÍDA]")
    print(f"Total de verbetes reais (não-redirecionamentos): {numero_final_verbetes}")
    print("="*50)
    print("\nEste número deve corresponder à contagem oficial de artigos do Wikifavelas.")

if __name__ == '__main__':
    main()
# Out:
# [INICIANDO VALIDAÇÃO] Listando verbetes reais (não-redirecionamentos)...
#   [INFO] Lote recebido. Total parcial: 500 verbetes...
#   [INFO] Lote recebido. Total parcial: 1000 verbetes...
#   [INFO] Lote recebido. Total parcial: 1500 verbetes...
#   [INFO] Lote recebido. Total parcial: 2000 verbetes...
#   [INFO] Lote recebido. Total parcial: 2500 verbetes...
#   [INFO] Lote recebido. Total parcial: 3000 verbetes...
#   [INFO] Lote recebido. Total parcial: 3272 verbetes...
#
# ...
# [VALIDAÇÃO CONCLUÍDA]
# Total de verbetes reais (não-redirecionamentos): 3272
# ...
#
# Este número deve corresponder à contagem oficial de artigos do Wikifavelas.

# %%
import json
import pandas as pd # Importar pandas para DataFrames e Excel
from pathlib import Path

def encontrar_e_salvar_referencias_quebradas(): # Renomeado para refletir a ação de salvar
    """
    Identifica referências cujas CHAVES NORMALIZADAS não correspondem
    a nenhuma CHAVE DE TÍTULO válida. Salva os resultados (referências
    quebradas e lista de títulos válidos) em um arquivo Excel.
    """
    
    # --- 1. Definição de Caminhos ---
    INPUT_DIR = Path('../dados')
    INPUT_FILENAME = 'dados_com_referencias_normalizadas.json' 
    OUTPUT_DIR = Path('../dados/IndicadoresGerais') # Mesmo diretório de saída
    OUTPUT_EXCEL_FILENAME = 'analise_referencias_quebradas.xlsx' # Nome do arquivo Excel
    
    input_path = INPUT_DIR / INPUT_FILENAME
    output_excel_path = OUTPUT_DIR / OUTPUT_EXCEL_FILENAME # Caminho completo para o Excel
    
    if not input_path.exists():
        print(f"ERRO: Arquivo com chaves normalizadas não encontrado em: {input_path}")
        return

    # --- 2. Carregar o Arquivo JSON com Chaves ---
    print(f"Carregando dados com chaves normalizadas do arquivo: {input_path}")
    try:
        with open(input_path, 'r', encoding='utf-8') as f:
            dados = json.load(f)
    except Exception as e:
        print(f"Erro ao carregar ou decodificar o JSON: {e}")
        return
        
    verbetes_lista_json = dados.get('verbetes_completo', [])
    if not verbetes_lista_json:
        print("ERRO: O arquivo JSON não contém a chave 'verbetes_completo' ou ela está vazia.")
        return

    # --- 3. Criar Conjunto de Chaves Válidas e Lista de Títulos Válidos ---
    print("Criando conjunto de chaves e lista de títulos válidos...")
    titulos_keys_validos = set()
    titulos_originais_validos = [] # Lista para a segunda aba do Excel
    
    for verbete in verbetes_lista_json:
        titulo_key = verbete.get('titulo_key')
        titulo_original = verbete.get('titulo')
        
        if titulo_key: 
            titulos_keys_validos.add(titulo_key)
        if titulo_original: # Adiciona o título original à lista
             titulos_originais_validos.append(titulo_original)
    
    print(f"Total de {len(titulos_keys_validos)} chaves de títulos únicas válidas encontradas.")
    print(f"Total de {len(titulos_originais_validos)} títulos originais válidos encontrados.")


    # --- 4. Iterar e Verificar Referências Usando Chaves Normalizadas ---
    print("\nVerificando referências usando chaves normalizadas...")
    referencias_quebradas_norm = [] 

    for verbete_origem in verbetes_lista_json:
        titulo_origem = verbete_origem.get('titulo', 'TÍTULO AUSENTE')
        referencias_keys = verbete_origem.get('referencias_key', [])
        refs_originais = verbete_origem.get('referencias', []) # Pega a lista original filtrada

        # Itera pelo índice para poder mapear ref_key de volta para ref_original
        for idx, ref_key in enumerate(referencias_keys):
            if ref_key: 
                if ref_key not in titulos_keys_validos:
                    # Pega a referência original correspondente ao índice
                    ref_original = refs_originais[idx] if idx < len(refs_originais) else "ERRO: Original não encontrada"
                              
                    referencias_quebradas_norm.append({
                        # Renomeando chaves para nomes de colunas mais claros
                        'Verbete Origem': titulo_origem,
                        'Referencia Original': ref_original,
                        'Chave Normalizada Nao Encontrada': ref_key
                    })

    # --- 5. Preparar DataFrames e Salvar em Excel ---
    total_quebradas_norm = len(referencias_quebradas_norm)
    print(f"\nTotal de referências quebradas (após normalização): {total_quebradas_norm}")

    try:
        print(f"Preparando dados para salvar no Excel em: {output_excel_path}")
        # Cria o DataFrame para as referências quebradas
        df_quebradas = pd.DataFrame(referencias_quebradas_norm)
        
        # Cria o DataFrame para a lista de títulos válidos
        df_titulos = pd.DataFrame({'Titulo Valido': sorted(titulos_originais_validos)}) # Ordena alfabeticamente

        # Usa ExcelWriter para salvar em múltiplas abas
        with pd.ExcelWriter(output_excel_path, engine='xlsxwriter') as writer:
            df_quebradas.to_excel(writer, sheet_name='Referencias Quebradas', index=False)
            df_titulos.to_excel(writer, sheet_name='Titulos Validos', index=False)
            
            # Opcional: Ajustar largura das colunas (exemplo para a primeira aba)
            # worksheet_quebradas = writer.sheets['Referencias Quebradas']
            # worksheet_quebradas.set_column('A:A', 50) # Coluna A (Verbete Origem) com 50 de largura
            # worksheet_quebradas.set_column('B:B', 50) # Coluna B (Referencia Original) com 50
            # worksheet_quebradas.set_column('C:C', 40) # Coluna C (Chave) com 40

        print("\n" + "="*50)
        print("✅ SUCESSO!")
        print(f"Arquivo Excel salvo em: {output_excel_path.resolve()}")
        print(f"  - Aba 'Referencias Quebradas' contém {total_quebradas_norm} entradas.")
        print(f"  - Aba 'Titulos Validos' contém {len(titulos_originais_validos)} entradas.")
        print("="*50)
        
    except Exception as e:
        print(f"\nERRO ao criar ou salvar o arquivo Excel: {e}")
        print("Verifique se a biblioteca 'pandas' e 'xlsxwriter' estão instaladas (`pip install pandas xlsxwriter`)")
        print("e se você tem permissão de escrita no diretório.")


# --- Execução ---
if __name__ == '__main__':
    encontrar_e_salvar_referencias_quebradas() # Chama a função renomeada
# Out:
# Carregando dados com chaves normalizadas do arquivo: ..\dados\dados_com_referencias_normalizadas.json
# Criando conjunto de chaves e lista de títulos válidos...
# Total de 3260 chaves de títulos únicas válidas encontradas.
# Total de 3272 títulos originais válidos encontrados.
#
# Verificando referências usando chaves normalizadas...
#
# Total de referências quebradas (após normalização): 1412
# Preparando dados para salvar no Excel em: ..\dados\IndicadoresGerais\analise_referencias_quebradas.xlsx
#
# ...
# ✅ SUCESSO!
# Arquivo Excel salvo em: C:\Users\GlauberGuimarãesBati\Desktop\Wikifavelas TCC\dados\IndicadoresGerais\analise_referencias_quebradas.xlsx
#   - Aba 'Referencias Quebradas' contém 1412 entradas.
#   - Aba 'Titulos Validos' contém 3272 entradas.
# ...

# %%
# script_match_referencias_fuzzy_completo_v2.py
#
# Objetivo: Tentar encontrar correspondências para as referências quebradas
# usando similaridade de string (fuzzy matching) com lógica aprimorada
# para reduzir falsos positivos (Opção 1).
# Salva as sugestões detalhadas (6 colunas) em uma nova aba
# no mesmo arquivo Excel original ('analise_referencias_quebradas.xlsx').

import pandas as pd
from pathlib import Path
from thefuzz import process, fuzz # Importa a biblioteca thefuzz
import math # Para checar se é NaN
# Certifique-se de ter instalado pandas, openpyxl, thefuzz[speedup]
# pip install pandas openpyxl thefuzz[speedup]

def match_referencias_com_fuzzy_detalhado_opcao1():
    """
    Lê o Excel, tenta encontrar matches usando fuzzy matching com filtro
    de ratio mínimo para partial matches, e salva sugestões detalhadas
    em uma nova aba do mesmo arquivo.
    """
    
    # --- 1. Definição de Caminhos ---
    DATA_DIR = Path('../dados/IndicadoresGerais')
    # Arquivo Excel GERADO pelo script anterior
    INPUT_EXCEL = DATA_DIR / 'analise_referencias_quebradas.xlsx' 
    # O arquivo de SAÍDA será o mesmo arquivo de ENTRADA (modificado)
    OUTPUT_EXCEL = INPUT_EXCEL 
    # Nome da NOVA ABA a ser criada/substituída no Excel
    OUTPUT_SHEET_NAME = 'Sugestoes Match Detalhadas V6' # Nome da aba atualizado

    # --- Limiares de Similaridade ---
    SIMILARITY_THRESHOLD_PARTIAL = 80  # Limiar para considerar um match parcial
    SIMILARITY_THRESHOLD_RATIO = 80    # Limiar para considerar um match ratio (alta confiança)
    # --- NOVO: Limiar Mínimo de Ratio para aceitar um Match Parcial ---
    MINIMUM_RATIO_FOR_PARTIAL = 50     # Ajuste este valor (0-100) conforme necessário

    if not INPUT_EXCEL.exists():
        print(f"ERRO: Arquivo Excel de entrada não encontrado em: {INPUT_EXCEL}")
        print("Certifique-se de que o script 'encontrar_e_salvar_referencias_quebradas.py' foi executado.")
        return

    # --- 2. Carregar Dados do Excel ---
    print(f"Carregando dados de '{INPUT_EXCEL}'...")
    try:
        # Especifica o engine para robustez
        df_quebradas = pd.read_excel(INPUT_EXCEL, sheet_name='Referencias Quebradas', engine='openpyxl') 
        df_titulos = pd.read_excel(INPUT_EXCEL, sheet_name='Titulos Validos', engine='openpyxl') 
        
        titulos_validos_lista = [str(t) for t in df_titulos['Titulo Valido'].tolist() if isinstance(t, str) and t] 
        if not titulos_validos_lista:
             print("ERRO: A aba 'Titulos Validos' está vazia ou não contém strings válidas.")
             return

    except Exception as e:
        print(f"Erro ao carregar o arquivo Excel: {e}")
        print("Verifique se as abas 'Referencias Quebradas' e 'Titulos Validos' existem e se 'openpyxl' está instalado.")
        return

    # --- 3. Processar Referências Quebradas com Lógica Aprimorada ---
    print(f"Processando {len(df_quebradas)} referências quebradas para encontrar matches (Lógica Opção 1)...")
    resultados = []
    
    for index, row in df_quebradas.iterrows():
        origem = row['Verbete Origem']
        ref_original = row['Referencia Original']
        ref_key_quebrada = row['Chave Normalizada Nao Encontrada']
        
        ref_original_str = str(ref_original) if ref_original and not pd.isna(ref_original) else ""

        if not ref_original_str:
             resultados.append({
                'Verbete Origem': origem, 'Referencia Original': ref_original,
                'Chave Normalizada': ref_key_quebrada, 'Titulo Valido Sugerido': 'N/A (Ref Original Vazia)',
                'Score Ratio': 0, 'Score Partial': 0
            })
             continue

        # 1. Tenta encontrar o melhor match com RATIO (alta confiança)
        best_match_ratio_tuple = process.extractOne(
            ref_original_str, 
            titulos_validos_lista, 
            scorer=fuzz.ratio, 
            score_cutoff=SIMILARITY_THRESHOLD_RATIO 
        )

        # 2. Tenta encontrar o melhor match com PARTIAL RATIO
        best_match_partial_tuple = process.extractOne(
            ref_original_str, 
            titulos_validos_lista, 
            scorer=fuzz.partial_ratio, 
            score_cutoff=SIMILARITY_THRESHOLD_PARTIAL 
        )

        sugestao_final = "Nenhum match encontrado acima dos limiares"
        score_ratio_final = 0
        score_partial_final = 0
        
        # 3. Lógica de Decisão Aprimorada (Opção 1)
        if best_match_ratio_tuple:
            # Se encontrou um match RATIO forte, usa ele (prioridade)
            sugestao_final = best_match_ratio_tuple[0]
            score_ratio_final = best_match_ratio_tuple[1]
            # Calcula o partial score correspondente apenas para informação
            score_partial_final = fuzz.partial_ratio(ref_original_str, sugestao_final)
            
        elif best_match_partial_tuple:
            # Se NÃO encontrou ratio forte, MAS encontrou partial forte...
            sugestao_parcial = best_match_partial_tuple[0]
            score_parcial_candidato = best_match_partial_tuple[1]
            
            # ... Calcula o RATIO para ESTA sugestão parcial ...
            ratio_da_sugestao_parcial = fuzz.ratio(ref_original_str, sugestao_parcial)
            
            # ... E SÓ ACEITA se o RATIO for aceitável (acima do novo limiar mínimo)
            if ratio_da_sugestao_parcial >= MINIMUM_RATIO_FOR_PARTIAL: # <<< FILTRO APLICADO
                sugestao_final = sugestao_parcial
                score_partial_final = score_parcial_candidato
                score_ratio_final = ratio_da_sugestao_parcial # Guarda o ratio calculado
            # else: A sugestão parcial foi rejeitada por ter ratio muito baixo. 
            #        'sugestao_final' permanece como "Nenhum match..."
                
        # else: Nenhum match ratio ou partial (aceitável) foi encontrado

        # Adiciona ao resultado (estrutura solicitada)
        resultados.append({
            'Verbete Origem': origem,
            'Referencia Original': ref_original,
            'Chave Normalizada': ref_key_quebrada, 
            'Titulo Valido Sugerido': sugestao_final,
            'Score Ratio': score_ratio_final,
            'Score Partial': score_partial_final
        })
        
        if (index + 1) % 100 == 0:
            print(f"  Processadas {index + 1}/{len(df_quebradas)} referências...")

    # --- 4. Salvar Resultados Detalhados em Nova Aba do Excel Existente ---
    print(f"\nAdicionando/Atualizando aba '{OUTPUT_SHEET_NAME}' no arquivo '{OUTPUT_EXCEL}'...")
    try:
        df_resultados_detalhados = pd.DataFrame(resultados)
        
        with pd.ExcelWriter(
            OUTPUT_EXCEL,
            mode='a', 
            engine='openpyxl',
            if_sheet_exists='replace' 
        ) as writer:
            df_resultados_detalhados.to_excel(writer, sheet_name=OUTPUT_SHEET_NAME, index=False)

            # Ajustar largura das colunas na nova aba
            worksheet_sugestoes = writer.sheets[OUTPUT_SHEET_NAME]
            worksheet_sugestoes.column_dimensions['A'].width = 40 # Verbete Origem
            worksheet_sugestoes.column_dimensions['B'].width = 50 # Referencia Original
            worksheet_sugestoes.column_dimensions['C'].width = 40 # Chave Normalizada
            worksheet_sugestoes.column_dimensions['D'].width = 50 # Titulo Valido Sugerido
            worksheet_sugestoes.column_dimensions['E'].width = 15 # Score Ratio
            worksheet_sugestoes.column_dimensions['F'].width = 15 # Score Partial

        print("\n" + "="*50)
        print("✅ SUCESSO!")
        print(f"Nova aba '{OUTPUT_SHEET_NAME}' adicionada/atualizada em: {OUTPUT_EXCEL.resolve()}")
        print(f"   Contendo {len(df_resultados_detalhados)} sugestões detalhadas.")
        print("="*50)
        print("\nIMPORTANTE: Revise manualmente as sugestões na aba '{OUTPUT_SHEET_NAME}'")
        print("            antes de usá-las para corrigir os dados ou o grafo.")

    except FileNotFoundError:
         print(f"ERRO: O arquivo Excel base '{INPUT_EXCEL}' não foi encontrado.")
    except ImportError:
        print("\nERRO: A biblioteca 'openpyxl' é necessária para modificar arquivos Excel.")
        print("Instale-a com: pip install openpyxl")
    except Exception as e:
        print(f"\nERRO ao modificar ou salvar o arquivo Excel: {e}")
        print("Verifique se o arquivo não está aberto em outro programa,")
        print("se as bibliotecas necessárias estão instaladas e se você tem permissão de escrita.")

# --- Execução ---
if __name__ == '__main__':
    match_referencias_com_fuzzy_detalhado_opcao1()
# Out:
# Carregando dados de '..\dados\IndicadoresGerais\analise_referencias_quebradas.xlsx'...
# Processando 1412 referências quebradas para encontrar matches (Lógica Opção 1)...
#   Processadas 100/1412 referências...
#   Processadas 200/1412 referências...
#   Processadas 300/1412 referências...
#   Processadas 400/1412 referências...
#   Processadas 500/1412 referências...
#   Processadas 600/1412 referências...
#   Processadas 700/1412 referências...
#   Processadas 800/1412 referências...
#   Processadas 900/1412 referências...
#   Processadas 1000/1412 referências...
#   Processadas 1100/1412 referências...
#   Processadas 1200/1412 referências...
#   Processadas 1300/1412 referências...
#   Processadas 1400/1412 referências...
#
# Adicionando/Atualizando aba 'Sugestoes Match Detalhadas V6' no arquivo '..\dados\IndicadoresGerais\analise_referencias_quebradas.xlsx'...
#
# ...
# ✅ SUCESSO!
# ...
